# %% [markdown]
# # Tutorial using the PBMC bulk ATAC-seq

# %%
# %load_ext autoreload
# %autoreload 2
import scprinter as scp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time
import pandas as pd
import numpy as np
import os
import pickle
import torch
import matplotlib as mpl
mpl.rcParams['pdf.fonttype'] = 42
from scanpy.plotting.palettes import zeileis_28
from tqdm.contrib.concurrent import *
from tqdm.auto import *
import anndata
import scanpy as sc
import json
import csv
import re
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# In this tutorial, we will test run PRINT/seq2PRINT on bulk ATAC samples. In bulk ATAC-seq, you typically will have separate fragments files for each sample (in contrast to single-cell, where there is a single framents file with barcode labels corresponding to single cells). We recommend you use scPrinter to simply load each individual fragments file together as shown below. In the individual fragments file, each line of the barcode column populated with the name of the sample. Therefore, we are essentially treating each bulk sample as a "big cell".
#
# The dataset is a simulated bulk ATAC dataset by sampling from the 10x PBMC 5k single cell dataset. This is to help you compare and contrast with our scATAC tutorial which uses the same dataset. We similuate 2 bulk ATAC samples from each major cell type (B cell, monocyte, T cell). Although this dataset is simulated bulk-ATAC, the data format and how we run scPrinter is exactly the same as real bulk ATAC data.

# %%
main_dir = '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial/'
work_dir = f'{main_dir}/seq2print'
if not os.path.exists(work_dir):
    os.system("mkdir -p " + work_dir)
frag_dir = f'{main_dir}/fragments'
if not os.path.exists(frag_dir):
    os.system("mkdir -p " + frag_dir)

# %%
# Download the fragments files of bulk samples from our Zenodo repository https://zenodo.org/records/14866808 using the code below
samples = ["Bcell_0", "Bcell_1", "Monocyte_0", "Monocyte_1", "Tcell_0", "Tcell_1"]
for sample in samples:
    link_prefix = "https://zenodo.org/records/14866808/files/PBMC_bulk_ATAC_tutorial_"
    link_suffix = "_frags.tsv.gz?download=1"
    os.system(f"wget -O {frag_dir}/{sample}_frags.tsv.gz {link_prefix}{sample}{link_suffix}")
# Out:
# --2025-02-17 15:41:40--  https://zenodo.org/records/14866808/files/PBMC_bulk_ATAC_tutorial_Bcell_0_frags.tsv.gz?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.48.194, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92267715 (88M) [application/octet-stream]
# Saving to: ‘/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_0_frags.tsv.gz’
#
#      0K .......... .......... .......... .......... ..........  0%  308K 4m52s
#     50K .......... .......... .......... .......... ..........  0% 2.36M 2m45s
#    100K .......... .......... .......... .......... ..........  0%  618K 2m38s
#    150K .......... .......... .......... .......... ..........  0%  151M 1m59s
#    200K .......... .......... .......... .......... ..........  0% 7.50M 97s
#    250K .......... .......... .......... .......... ..........  0%  676K 1m43s
#    300K .......... .......... .......... .......... ..........  0%  116M 88s
#    350K .......... .......... .......... .......... ..........  0%  207M 77s
#    400K .......... .......... .......... .......... ..........  0%  214M 69s
#    450K .......... .......... .......... .......... ..........  0% 8.05M 63s
#    500K .......... .......... .......... .......... ..........  0%  931K 66s
#    550K .......... .......... .......... .......... ..........  0% 2.41M 63s
#    600K .......... .......... .......... .......... ..........  0%  135M 59s
#    650K .......... .......... .......... .......... ..........  0%  170M 54s
#    700K .......... .......... .......... .......... ..........  0%  214M 51s
#    750K .......... .......... .......... .......... ..........  0%  240M 48s
#    800K .......... .......... .......... .......... ..........  0%  243M 45s
#    850K .......... .......... .......... .......... ..........  0%  248M 42s
#    900K .......... .......... .......... .......... ..........  1%  158M 40s
#    950K .......... .......... .......... .......... ..........  1% 9.31M 39s
#   1000K .......... .......... .......... .......... ..........  1%  175M 37s
#   1050K .......... .......... .......... .......... ..........  1%  206M 35s
#   1100K .......... .......... .......... .......... ..........  1%  934K 38s
#   1150K .......... .......... .......... .......... ..........  1% 2.46M 38s
#   1200K .......... .......... .......... .......... ..........  1%  139M 36s
#   1250K .......... .......... .......... .......... ..........  1%  163M 35s
#   1300K .......... .......... .......... .......... ..........  1%  148M 33s
#   1350K .......... .......... .......... .......... ..........  1%  252M 32s
#   1400K .......... .......... .......... .......... ..........  1%  255M 31s
#   1450K .......... .......... .......... .......... ..........  1%  253M 30s
#   1500K .......... .......... .......... .......... ..........  1%  209M 29s
#   1550K .......... .......... .......... .......... ..........  1%  241M 28s
#   1600K .......... .......... .......... .......... ..........  1%  248M 27s
#   1650K .......... .......... .......... .......... ..........  1%  209M 26s
#   1700K .......... .......... .......... .......... ..........  1%  252M 26s
#   1750K .......... .......... .......... .......... ..........  1%  229M 25s
#   1800K .......... .......... .......... .......... ..........  2%  242M 24s
#   1850K .......... .......... .......... .......... ..........  2%  237M 24s
#   1900K .......... .......... .......... .......... ..........  2%  257M 23s
#   1950K .......... .......... .......... .......... ..........  2% 13.9M 23s
#   2000K .......... .......... .......... .......... ..........  2%  153M 22s
#   2050K .......... .......... .......... .......... ..........  2%  194M 22s
#   2100K .......... .......... .......... .......... ..........  2%  260M 21s
#   2150K .......... .......... .......... .......... ..........  2%  225M 21s
#   2200K .......... .......... .......... .......... ..........  2%  920K 22s
#   2250K .......... .......... .......... .......... ..........  2%  207M 22s
#   2300K .......... .......... .......... .......... ..........  2%  247M 21s
#   2350K .......... .......... .......... .......... ..........  2% 2.65M 21s
#   2400K .......... .......... .......... .......... ..........  2%  167M 21s
#   2450K .......... .......... .......... .......... ..........  2%  143M 21s
#   2500K .......... .......... .......... .......... ..........  2%  182M 20s
#   2550K .......... .......... .......... .......... ..........  2%  177M 20s
#   2600K .......... .......... .......... .......... ..........  2%  203M 19s
#   2650K .......... .......... .......... .......... ..........  2%  236M 19s
#   2700K .......... .......... .......... .......... ..........  3%  224M 19s
#   2750K .......... .......... .......... .......... ..........  3%  236M 18s
#   2800K .......... .......... .......... .......... ..........  3%  202M 18s
#   2850K .......... .......... .......... .......... ..........  3%  252M 18s
#   2900K .......... .......... .......... .......... ..........  3%  245M 17s
#   2950K .......... .......... .......... .......... ..........  3%  219M 17s
#   3000K .......... .......... .......... .......... ..........  3%  222M 17s
#   3050K .......... .......... .......... .......... ..........  3%  251M 17s
#   3100K .......... .......... .......... .......... ..........  3%  234M 16s
#   3150K .......... .......... .......... .......... ..........  3%  257M 16s
#   3200K .......... .......... .......... .......... ..........  3%  198M 16s
#   3250K .......... .......... .......... .......... ..........  3%  217M 16s
#   3300K .......... .......... .......... .......... ..........  3%  233M 15s
#   3350K .......... .......... .......... .......... ..........  3%  260M 15s
#   3400K .......... .......... .......... .......... ..........  3%  208M 15s
#   3450K .......... .......... .......... .......... ..........  3%  244M 15s
#   3500K .......... .......... .......... .......... ..........  3%  240M 14s
#   3550K .......... .......... .......... .......... ..........  3%  264M 14s
#   3600K .......... .......... .......... .......... ..........  4%  187M 14s
#   3650K .......... .......... .......... .......... ..........  4%  240M 14s
#   3700K .......... .......... .......... .......... ..........  4%  241M 14s
#   3750K .......... .......... .......... .......... ..........  4%  232M 13s
#   3800K .......... .......... .......... .......... ..........  4%  243M 13s
#   3850K .......... .......... .......... .......... ..........  4%  221M 13s
#   3900K .......... .......... .......... .......... ..........  4%  192M 13s
#   3950K .......... .......... .......... .......... ..........  4%  155M 13s
#   4000K .......... .......... .......... .......... ..........  4%  237M 13s
#   4050K .......... .......... .......... .......... ..........  4%  239M 12s
#   4100K .......... .......... .......... .......... ..........  4%  225M 12s
#   4150K .......... .......... .......... .......... ..........  4%  219M 12s
#   4200K .......... .......... .......... .......... ..........  4%  238M 12s
#   4250K .......... .......... .......... .......... ..........  4%  225M 12s
#   4300K .......... .......... .......... .......... ..........  4%  230M 12s
#   4350K .......... .......... .......... .......... ..........  4%  162M 12s
#   4400K .......... .......... .......... .......... ..........  4% 1.26M 12s
#   4450K .......... .......... .......... .......... ..........  4% 3.77M 12s
#   4500K .......... .......... .......... .......... ..........  5% 32.2M 12s
#   4550K .......... .......... .......... .......... ..........  5%  243M 12s
#   4600K .......... .......... .......... .......... ..........  5%  194M 12s
#   4650K .......... .......... .......... .......... ..........  5%  245M 12s
#   4700K .......... .......... .......... .......... ..........  5%  263M 12s
#   4750K .......... .......... .......... .......... ..........  5% 2.76M 12s
#   4800K .......... .......... .......... .......... ..........  5%  109M 12s
#   4850K .......... .......... .......... .......... ..........  5% 99.3M 12s
#   4900K .......... .......... .......... .......... ..........  5%  161M 12s
#   4950K .......... .......... .......... .......... ..........  5%  208M 11s
#   5000K .......... .......... .......... .......... ..........  5%  210M 11s
#   5050K .......... .......... .......... .......... ..........  5%  178M 11s
#   5100K .......... .......... .......... .......... ..........  5%  178M 11s
#   5150K .......... .......... .......... .......... ..........  5%  195M 11s
#   5200K .......... .......... .......... .......... ..........  5%  203M 11s
#   5250K .......... .......... .......... .......... ..........  5%  214M 11s
#   5300K .......... .......... .......... .......... ..........  5%  236M 11s
#   5350K .......... .......... .......... .......... ..........  5%  238M 11s
#   5400K .......... .......... .......... .......... ..........  6%  223M 10s
#   5450K .......... .......... .......... .......... ..........  6%  221M 10s
#   5500K .......... .......... .......... .......... ..........  6%  229M 10s
#   5550K .......... .......... .......... .......... ..........  6%  186M 10s
#   5600K .......... .......... .......... .......... ..........  6%  219M 10s
#   5650K .......... .......... .......... .......... ..........  6%  253M 10s
#   5700K .......... .......... .......... .......... ..........  6%  221M 10s
#   5750K .......... .......... .......... .......... ..........  6%  218M 10s
#   5800K .......... .......... .......... .......... ..........  6%  237M 10s
#   5850K .......... .......... .......... .......... ..........  6%  255M 10s
#   5900K .......... .......... .......... .......... ..........  6%  237M 10s
#   5950K .......... .......... .......... .......... ..........  6%  190M 9s
#   6000K .......... .......... .......... .......... ..........  6%  220M 9s
#   6050K .......... .......... .......... .......... ..........  6%  233M 9s
#   6100K .......... .......... .......... .......... ..........  6%  125M 9s
#   6150K .......... .......... .......... .......... ..........  6%  165M 9s
#   6200K .......... .......... .......... .......... ..........  6%  186M 9s
#   6250K .......... .......... .......... .......... ..........  6%  194M 9s
#   6300K .......... .......... .......... .......... ..........  7%  215M 9s
#   6350K .......... .......... .......... .......... ..........  7%  191M 9s
#   6400K .......... .......... .......... .......... ..........  7%  218M 9s
#   6450K .......... .......... .......... .......... ..........  7%  243M 9s
#   6500K .......... .......... .......... .......... ..........  7%  219M 9s
#   6550K .......... .......... .......... .......... ..........  7%  229M 9s
#   6600K .......... .......... .......... .......... ..........  7%  237M 9s
#   6650K .......... .......... .......... .......... ..........  7%  237M 8s
#   6700K .......... .......... .......... .......... ..........  7%  193M 8s
#   6750K .......... .......... .......... .......... ..........  7%  244M 8s
#   6800K .......... .......... .......... .......... ..........  7%  222M 8s
#   6850K .......... .......... .......... .......... ..........  7%  227M 8s
#   6900K .......... .......... .......... .......... ..........  7%  219M 8s
#   6950K .......... .......... .......... .......... ..........  7%  241M 8s
#   7000K .......... .......... .......... .......... ..........  7%  234M 8s
#   7050K .......... .......... .......... .......... ..........  7%  250M 8s
#   7100K .......... .......... .......... .......... ..........  7%  211M 8s
#   7150K .......... .......... .......... .......... ..........  7% 1.33M 8s
#   7200K .......... .......... .......... .......... ..........  8%  131M 8s
#   7250K .......... .......... .......... .......... ..........  8%  150M 8s
#   7300K .......... .......... .......... .......... ..........  8%  149M 8s
#   7350K .......... .......... .......... .......... ..........  8%  177M 8s
#   7400K .......... .......... .......... .......... ..........  8% 97.7M 8s
#   7450K .......... .......... .......... .......... ..........  8%  182M 8s
#   7500K .......... .......... .......... .......... ..........  8% 4.41M 8s
#   7550K .......... .......... .......... .......... ..........  8% 37.8M 8s
#   7600K .......... .......... .......... .......... ..........  8% 46.0M 8s
#   7650K .......... .......... .......... .......... ..........  8%  171M 8s
#   7700K .......... .......... .......... .......... ..........  8%  147M 8s
#   7750K .......... .......... .......... .......... ..........  8%  104M 8s
#   7800K .......... .......... .......... .......... ..........  8% 2.96M 8s
#   7850K .......... .......... .......... .......... ..........  8%  132M 8s
#   7900K .......... .......... .......... .......... ..........  8%  115M 8s
#   7950K .......... .......... .......... .......... ..........  8%  124M 8s
#   8000K .......... .......... .......... .......... ..........  8%  165M 8s
#   8050K .......... .......... .......... .......... ..........  8%  137M 8s
#   8100K .......... .......... .......... .......... ..........  9%  163M 8s
#   8150K .......... .......... .......... .......... ..........  9%  159M 8s
#   8200K .......... .......... .......... .......... ..........  9%  118M 7s
#   8250K .......... .......... .......... .......... ..........  9%  168M 7s
#   8300K .......... .......... .......... .......... ..........  9%  204M 7s
#   8350K .......... .......... .......... .......... ..........  9%  199M 7s
#   8400K .......... .......... .......... .......... ..........  9%  161M 7s
#   8450K .......... .......... .......... .......... ..........  9%  201M 7s
#   8500K .......... .......... .......... .......... ..........  9%  211M 7s
#   8550K .......... .......... .......... .......... ..........  9% 21.5M 7s
#   8600K .......... .......... .......... .......... ..........  9%  147M 7s
#   8650K .......... .......... .......... .......... ..........  9%  165M 7s
#   8700K .......... .......... .......... .......... ..........  9%  163M 7s
#   8750K .......... .......... .......... .......... ..........  9%  208M 7s
#   8800K .......... .......... .......... .......... ..........  9%  173M 7s
#   8850K .......... .......... .......... .......... ..........  9%  205M 7s
#   8900K .......... .......... .......... .......... ..........  9%  212M 7s
#   8950K .......... .......... .......... .......... ..........  9%  197M 7s
#   9000K .......... .......... .......... .......... .......... 10%  197M 7s
#   9050K .......... .......... .......... .......... .......... 10%  209M 7s
#   9100K .......... .......... .......... .......... .......... 10%  178M 7s
#   9150K .......... .......... .......... .......... .......... 10%  204M 7s
#   9200K .......... .......... .......... .......... .......... 10%  170M 7s
#   9250K .......... .......... .......... .......... .......... 10%  216M 7s
#   9300K .......... .......... .......... .......... .......... 10%  209M 7s
#   9350K .......... .......... .......... .......... .......... 10%  192M 7s
#   9400K .......... .......... .......... .......... .......... 10%  177M 6s
#   9450K .......... .......... .......... .......... .......... 10%  161M 6s
#   9500K .......... .......... .......... .......... .......... 10%  181M 6s
#   9550K .......... .......... .......... .......... .......... 10% 1.34M 7s
#   9600K .......... .......... .......... .......... .......... 10%  117M 7s
#   9650K .......... .......... .......... .......... .......... 10%  145M 7s
#   9700K .......... .......... .......... .......... .......... 10%  150M 7s
#   9750K .......... .......... .......... .......... .......... 10%  161M 7s
#   9800K .......... .......... .......... .......... .......... 10%  162M 7s
#   9850K .......... .......... .......... .......... .......... 10%  153M 6s
#   9900K .......... .......... .......... .......... .......... 11%  203M 6s
#   9950K .......... .......... .......... .......... .......... 11%  188M 6s
#  10000K .......... .......... .......... .......... .......... 11%  192M 6s
#  10050K .......... .......... .......... .......... .......... 11%  149M 6s
#  10100K .......... .......... .......... .......... .......... 11%  183M 6s
#  10150K .......... .......... .......... .......... .......... 11%  181M 6s
#  10200K .......... .......... .......... .......... .......... 11% 5.22M 6s
#  10250K .......... .......... .......... .......... .......... 11%  122M 6s
#  10300K .......... .......... .......... .......... .......... 11%  131M 6s
#  10350K .......... .......... .......... .......... .......... 11%  134M 6s
#  10400K .......... .......... .......... .......... .......... 11%  156M 6s
#  10450K .......... .......... .......... .......... .......... 11%  225M 6s
#  10500K .......... .......... .......... .......... .......... 11%  204M 6s
#  10550K .......... .......... .......... .......... .......... 11%  170M 6s
#  10600K .......... .......... .......... .......... .......... 11%  199M 6s
#  10650K .......... .......... .......... .......... .......... 11%  203M 6s
#  10700K .......... .......... .......... .......... .......... 11% 2.82M 6s
#  10750K .......... .......... .......... .......... .......... 11%  156M 6s
#  10800K .......... .......... .......... .......... .......... 12%  148M 6s
#  10850K .......... .......... .......... .......... .......... 12%  151M 6s
#  10900K .......... .......... .......... .......... .......... 12%  191M 6s
#  10950K .......... .......... .......... .......... .......... 12%  168M 6s
#  11000K .......... .......... .......... .......... .......... 12%  193M 6s
#  11050K .......... .......... .......... .......... .......... 12%  189M 6s
#  11100K .......... .......... .......... .......... .......... 12%  208M 6s
#  11150K .......... .......... .......... .......... .......... 12%  202M 6s
#  11200K .......... .......... .......... .......... .......... 12%  134M 6s
#  11250K .......... .......... .......... .......... .......... 12%  192M 6s
#  11300K .......... .......... .......... .......... .......... 12% 82.1M 6s
#  11350K .......... .......... .......... .......... .......... 12%  171M 6s
#  11400K .......... .......... .......... .......... .......... 12%  190M 6s
#  11450K .......... .......... .......... .......... .......... 12% 18.2M 6s
#  11500K .......... .......... .......... .......... .......... 12%  120M 6s
#  11550K .......... .......... .......... .......... .......... 12%  148M 6s
#  11600K .......... .......... .......... .......... .......... 12%  187M 6s
#  11650K .......... .......... .......... .......... .......... 12%  181M 6s
#  11700K .......... .......... .......... .......... .......... 13%  173M 6s
#  11750K .......... .......... .......... .......... .......... 13%  180M 6s
#  11800K .......... .......... .......... .......... .......... 13%  142M 6s
#  11850K .......... .......... .......... .......... .......... 13%  176M 6s
#  11900K .......... .......... .......... .......... .......... 13%  182M 5s
#  11950K .......... .......... .......... .......... .......... 13%  171M 5s
#  12000K .......... .......... .......... .......... .......... 13% 1.10M 6s
#  12050K .......... .......... .......... .......... .......... 13%  151M 6s
#  12100K .......... .......... .......... .......... .......... 13%  166M 6s
#  12150K .......... .......... .......... .......... .......... 13%  161M 6s
#  12200K .......... .......... .......... .......... .......... 13%  219M 6s
#  12250K .......... .......... .......... .......... .......... 13%  228M 6s
#  12300K .......... .......... .......... .......... .......... 13%  217M 6s
#  12350K .......... .......... .......... .......... .......... 13%  241M 6s
#  12400K .......... .......... .......... .......... .......... 13%  241M 6s
#  12450K .......... .......... .......... .......... .......... 13%  241M 6s
#  12500K .......... .......... .......... .......... .......... 13%  176M 5s
#  12550K .......... .......... .......... .......... .......... 13%  188M 5s
#  12600K .......... .......... .......... .......... .......... 14%  203M 5s
#  12650K .......... .......... .......... .......... .......... 14%  197M 5s
#  12700K .......... .......... .......... .......... .......... 14%  205M 5s
#  12750K .......... .......... .......... .......... .......... 14%  174M 5s
#  12800K .......... .......... .......... .......... .......... 14% 17.7M 5s
#  12850K .......... .......... .......... .......... .......... 14%  120M 5s
#  12900K .......... .......... .......... .......... .......... 14%  164M 5s
#  12950K .......... .......... .......... .......... .......... 14%  144M 5s
#  13000K .......... .......... .......... .......... .......... 14%  163M 5s
#  13050K .......... .......... .......... .......... .......... 14%  166M 5s
#  13100K .......... .......... .......... .......... .......... 14%  193M 5s
#  13150K .......... .......... .......... .......... .......... 14%  213M 5s
#  13200K .......... .......... .......... .......... .......... 14%  167M 5s
#  13250K .......... .......... .......... .......... .......... 14%  195M 5s
#  13300K .......... .......... .......... .......... .......... 14%  176M 5s
#  13350K .......... .......... .......... .......... .......... 14%  185M 5s
#  13400K .......... .......... .......... .......... .......... 14%  179M 5s
#  13450K .......... .......... .......... .......... .......... 14%  189M 5s
#  13500K .......... .......... .......... .......... .......... 15%  178M 5s
#  13550K .......... .......... .......... .......... .......... 15%  179M 5s
#  13600K .......... .......... .......... .......... .......... 15% 2.96M 5s
#  13650K .......... .......... .......... .......... .......... 15%  173M 5s
#  13700K .......... .......... .......... .......... .......... 15%  123M 5s
#  13750K .......... .......... .......... .......... .......... 15%  212M 5s
#  13800K .......... .......... .......... .......... .......... 15%  210M 5s
#  13850K .......... .......... .......... .......... .......... 15%  189M 5s
#  13900K .......... .......... .......... .......... .......... 15%  208M 5s
#  13950K .......... .......... .......... .......... .......... 15%  245M 5s
#  14000K .......... .......... .......... .......... .......... 15%  240M 5s
#  14050K .......... .......... .......... .......... .......... 15%  164M 5s
#  14100K .......... .......... .......... .......... .......... 15%  239M 5s
#  14150K .......... .......... .......... .......... .......... 15%  235M 5s
#  14200K .......... .......... .......... .......... .......... 15%  223M 5s
#  14250K .......... .......... .......... .......... .......... 15%  179M 5s
#  14300K .......... .......... .......... .......... .......... 15%  222M 5s
#  14350K .......... .......... .......... .......... .......... 15%  237M 5s
#  14400K .......... .......... .......... .......... .......... 16% 19.1M 5s
#  14450K .......... .......... .......... .......... .......... 16%  177M 5s
#  14500K .......... .......... .......... .......... .......... 16%  130M 5s
#  14550K .......... .......... .......... .......... .......... 16%  215M 5s
#  14600K .......... .......... .......... .......... .......... 16%  200M 5s
#  14650K .......... .......... .......... .......... .......... 16%  235M 5s
#  14700K .......... .......... .......... .......... .......... 16% 54.7M 5s
#  14750K .......... .......... .......... .......... .......... 16%  234M 5s
#  14800K .......... .......... .......... .......... .......... 16%  194M 5s
#  14850K .......... .......... .......... .......... .......... 16% 1.27M 5s
#  14900K .......... .......... .......... .......... .......... 16%  173M 5s
#  14950K .......... .......... .......... .......... .......... 16%  174M 5s
#  15000K .......... .......... .......... .......... .......... 16%  154M 5s
#  15050K .......... .......... .......... .......... .......... 16% 8.38M 5s
#  15100K .......... .......... .......... .......... .......... 16%  182M 5s
#  15150K .......... .......... .......... .......... .......... 16%  210M 5s
#  15200K .......... .......... .......... .......... .......... 16%  161M 5s
#  15250K .......... .......... .......... .......... .......... 16%  198M 5s
#  15300K .......... .......... .......... .......... .......... 17% 9.72M 5s
#  15350K .......... .......... .......... .......... .......... 17%  159M 5s
#  15400K .......... .......... .......... .......... .......... 17%  127M 5s
#  15450K .......... .......... .......... .......... .......... 17%  148M 5s
#  15500K .......... .......... .......... .......... .......... 17%  213M 5s
#  15550K .......... .......... .......... .......... .......... 17%  204M 5s
#  15600K .......... .......... .......... .......... .......... 17%  157M 5s
#  15650K .......... .......... .......... .......... .......... 17%  186M 5s
#  15700K .......... .......... .......... .......... .......... 17%  206M 5s
#  15750K .......... .......... .......... .......... .......... 17%  197M 5s
#  15800K .......... .......... .......... .......... .......... 17%  183M 5s
#  15850K .......... .......... .......... .......... .......... 17%  191M 5s
#  15900K .......... .......... .......... .......... .......... 17%  220M 5s
#  15950K .......... .......... .......... .......... .......... 17%  211M 5s
#  16000K .......... .......... .......... .......... .......... 17%  168M 5s
#  16050K .......... .......... .......... .......... .......... 17%  194M 4s
#  16100K .......... .......... .......... .......... .......... 17%  197M 4s
#  16150K .......... .......... .......... .......... .......... 17%  212M 4s
#  16200K .......... .......... .......... .......... .......... 18%  203M 4s
#  16250K .......... .......... .......... .......... .......... 18%  203M 4s
#  16300K .......... .......... .......... .......... .......... 18%  211M 4s
#  16350K .......... .......... .......... .......... .......... 18% 3.14M 4s
#  16400K .......... .......... .......... .......... .......... 18%  145M 4s
#  16450K .......... .......... .......... .......... .......... 18%  194M 4s
#  16500K .......... .......... .......... .......... .......... 18%  188M 4s
#  16550K .......... .......... .......... .......... .......... 18%  184M 4s
#  16600K .......... .......... .......... .......... .......... 18%  185M 4s
#  16650K .......... .......... .......... .......... .......... 18%  211M 4s
#  16700K .......... .......... .......... .......... .......... 18%  208M 4s
#  16750K .......... .......... .......... .......... .......... 18%  159M 4s
#  16800K .......... .......... .......... .......... .......... 18%  173M 4s
#  16850K .......... .......... .......... .......... .......... 18%  192M 4s
#  16900K .......... .......... .......... .......... .......... 18%  192M 4s
#  16950K .......... .......... .......... .......... .......... 18%  180M 4s
#  17000K .......... .......... .......... .......... .......... 18%  195M 4s
#  17050K .......... .......... .......... .......... .......... 18%  208M 4s
#  17100K .......... .......... .......... .......... .......... 19%  176M 4s
#  17150K .......... .......... .......... .......... .......... 19%  168M 4s
#  17200K .......... .......... .......... .......... .......... 19%  208M 4s
#  17250K .......... .......... .......... .......... .......... 19%  237M 4s
#  17300K .......... .......... .......... .......... .......... 19%  231M 4s
#  17350K .......... .......... .......... .......... .......... 19% 38.7M 4s
#  17400K .......... .......... .......... .......... .......... 19%  195M 4s
#  17450K .......... .......... .......... .......... .......... 19%  207M 4s
#  17500K .......... .......... .......... .......... .......... 19%  104M 4s
#  17550K .......... .......... .......... .......... .......... 19%  203M 4s
#  17600K .......... .......... .......... .......... .......... 19%  207M 4s
#  17650K .......... .......... .......... .......... .......... 19% 55.6M 4s
#  17700K .......... .......... .......... .......... .......... 19%  187M 4s
#  17750K .......... .......... .......... .......... .......... 19%  190M 4s
#  17800K .......... .......... .......... .......... .......... 19% 1.26M 4s
#  17850K .......... .......... .......... .......... .......... 19%  210M 4s
#  17900K .......... .......... .......... .......... .......... 19% 7.75M 4s
#  17950K .......... .......... .......... .......... .......... 19%  235M 4s
#  18000K .......... .......... .......... .......... .......... 20%  224M 4s
#  18050K .......... .......... .......... .......... .......... 20%  105M 4s
#  18100K .......... .......... .......... .......... .......... 20%  189M 4s
#  18150K .......... .......... .......... .......... .......... 20%  191M 4s
#  18200K .......... .......... .......... .......... .......... 20%  189M 4s
#  18250K .......... .......... .......... .......... .......... 20%  174M 4s
#  18300K .......... .......... .......... .......... .......... 20% 11.5M 4s
#  18350K .......... .......... .......... .......... .......... 20%  103M 4s
#  18400K .......... .......... .......... .......... .......... 20%  147M 4s
#  18450K .......... .......... .......... .......... .......... 20%  179M 4s
#  18500K .......... .......... .......... .......... .......... 20%  130M 4s
#  18550K .......... .......... .......... .......... .......... 20%  175M 4s
#  18600K .......... .......... .......... .......... .......... 20%  190M 4s
#  18650K .......... .......... .......... .......... .......... 20%  136M 4s
#  18700K .......... .......... .......... .......... .......... 20%  176M 4s
#  18750K .......... .......... .......... .......... .......... 20%  246M 4s
#  18800K .......... .......... .......... .......... .......... 20%  237M 4s
#  18850K .......... .......... .......... .......... .......... 20%  262M 4s
#  18900K .......... .......... .......... .......... .......... 21%  251M 4s
#  18950K .......... .......... .......... .......... .......... 21% 1.08M 4s
#  19000K .......... .......... .......... .......... .......... 21%  206M 4s
#  19050K .......... .......... .......... .......... .......... 21%  219M 4s
#  19100K .......... .......... .......... .......... .......... 21%  285M 4s
#  19150K .......... .......... .......... .......... .......... 21%  264M 4s
#  19200K .......... .......... .......... .......... .......... 21%  278M 4s
#  19250K .......... .......... .......... .......... .......... 21%  314M 4s
#  19300K .......... .......... .......... .......... .......... 21%  302M 4s
#  19350K .......... .......... .......... .......... .......... 21%  249M 4s
#  19400K .......... .......... .......... .......... .......... 21%  334M 4s
#  19450K .......... .......... .......... .......... .......... 21%  284M 4s
#  19500K .......... .......... .......... .......... .......... 21%  282M 4s
#  19550K .......... .......... .......... .......... .......... 21%  275M 4s
#  19600K .......... .......... .......... .......... .......... 21%  338M 4s
#  19650K .......... .......... .......... .......... .......... 21%  306M 4s
#  19700K .......... .......... .......... .......... .......... 21%  308M 4s
#  19750K .......... .......... .......... .......... .......... 21%  251M 4s
#  19800K .......... .......... .......... .......... .......... 22%  306M 4s
#  19850K .......... .......... .......... .......... .......... 22%  334M 4s
#  19900K .......... .......... .......... .......... .......... 22%  287M 4s
#  19950K .......... .......... .......... .......... .......... 22%  287M 4s
#  20000K .......... .......... .......... .......... .......... 22%  320M 4s
#  20050K .......... .......... .......... .......... .......... 22%  337M 4s
#  20100K .......... .......... .......... .......... .......... 22%  265M 4s
#  20150K .......... .......... .......... .......... .......... 22%  304M 4s
#  20200K .......... .......... .......... .......... .......... 22%  314M 4s
#  20250K .......... .......... .......... .......... .......... 22%  312M 4s
#  20300K .......... .......... .......... .......... .......... 22%  271M 4s
#  20350K .......... .......... .......... .......... .......... 22%  320M 4s
#  20400K .......... .......... .......... .......... .......... 22%  321M 4s
#  20450K .......... .......... .......... .......... .......... 22%  317M 4s
#  20500K .......... .......... .......... .......... .......... 22%  264M 4s
#  20550K .......... .......... .......... .......... .......... 22%  335M 4s
#  20600K .......... .......... .......... .......... .......... 22%  332M 4s
#  20650K .......... .......... .......... .......... .......... 22%  339M 4s
#  20700K .......... .......... .......... .......... .......... 23%  282M 4s
#  20750K .......... .......... .......... .......... .......... 23% 3.69M 4s
#  20800K .......... .......... .......... .......... .......... 23%  260M 4s
#  20850K .......... .......... .......... .......... .......... 23% 7.32M 4s
#  20900K .......... .......... .......... .......... .......... 23%  216M 4s
#  20950K .......... .......... .......... .......... .......... 23%  280M 4s
#  21000K .......... .......... .......... .......... .......... 23%  116M 4s
#  21050K .......... .......... .......... .......... .......... 23%  281M 4s
#  21100K .......... .......... .......... .......... .......... 23%  339M 4s
#  21150K .......... .......... .......... .......... .......... 23% 9.37M 4s
#  21200K .......... .......... .......... .......... .......... 23%  280M 4s
#  21250K .......... .......... .......... .......... .......... 23%  138M 4s
#  21300K .......... .......... .......... .......... .......... 23%  265M 4s
#  21350K .......... .......... .......... .......... .......... 23%  289M 4s
#  21400K .......... .......... .......... .......... .......... 23%  286M 4s
#  21450K .......... .......... .......... .......... .......... 23%  151M 4s
#  21500K .......... .......... .......... .......... .......... 23%  280M 4s
#  21550K .......... .......... .......... .......... .......... 23%  250M 4s
#  21600K .......... .......... .......... .......... .......... 24% 93.7M 4s
#  21650K .......... .......... .......... .......... .......... 24%  201M 4s
#  21700K .......... .......... .......... .......... .......... 24%  260M 4s
#  21750K .......... .......... .......... .......... .......... 24%  292M 4s
#  21800K .......... .......... .......... .......... .......... 24% 2.64M 4s
#  21850K .......... .......... .......... .......... .......... 24% 9.87M 4s
#  21900K .......... .......... .......... .......... .......... 24%  112M 4s
#  21950K .......... .......... .......... .......... .......... 24%  207M 4s
#  22000K .......... .......... .......... .......... .......... 24%  185M 4s
#  22050K .......... .......... .......... .......... .......... 24%  283M 4s
#  22100K .......... .......... .......... .......... .......... 24%  276M 4s
#  22150K .......... .......... .......... .......... .......... 24%  290M 4s
#  22200K .......... .......... .......... .......... .......... 24%  263M 4s
#  22250K .......... .......... .......... .......... .......... 24%  293M 4s
#  22300K .......... .......... .......... .......... .......... 24%  258M 4s
#  22350K .......... .......... .......... .......... .......... 24%  287M 4s
#  22400K .......... .......... .......... .......... .......... 24% 2.39M 4s
#  22450K .......... .......... .......... .......... .......... 24%  277M 4s
#  22500K .......... .......... .......... .......... .......... 25% 2.58M 4s
#  22550K .......... .......... .......... .......... .......... 25% 54.6M 4s
#  22600K .......... .......... .......... .......... .......... 25%  253M 4s
#  22650K .......... .......... .......... .......... .......... 25%  282M 4s
#  22700K .......... .......... .......... .......... .......... 25%  240M 4s
#  22750K .......... .......... .......... .......... .......... 25%  253M 4s
#  22800K .......... .......... .......... .......... .......... 25%  236M 4s
#  22850K .......... .......... .......... .......... .......... 25%  287M 4s
#  22900K .......... .......... .......... .......... .......... 25%  296M 4s
#  22950K .......... .......... .......... .......... .......... 25%  257M 4s
#  23000K .......... .......... .......... .......... .......... 25%  274M 4s
#  23050K .......... .......... .......... .......... .......... 25%  283M 3s
#  23100K .......... .......... .......... .......... .......... 25%  272M 3s
#  23150K .......... .......... .......... .......... .......... 25%  221M 3s
#  23200K .......... .......... .......... .......... .......... 25%  282M 3s
#  23250K .......... .......... .......... .......... .......... 25%  277M 3s
#  23300K .......... .......... .......... .......... .......... 25%  275M 3s
#  23350K .......... .......... .......... .......... .......... 25%  232M 3s
#  23400K .......... .......... .......... .......... .......... 26%  258M 3s
#  23450K .......... .......... .......... .......... .......... 26%  261M 3s
#  23500K .......... .......... .......... .......... .......... 26%  266M 3s
#  23550K .......... .......... .......... .......... .......... 26%  193M 3s
#  23600K .......... .......... .......... .......... .......... 26%  267M 3s
#  23650K .......... .......... .......... .......... .......... 26%  266M 3s
#  23700K .......... .......... .......... .......... .......... 26%  269M 3s
#  23750K .......... .......... .......... .......... .......... 26%  242M 3s
#  23800K .......... .......... .......... .......... .......... 26%  252M 3s
#  23850K .......... .......... .......... .......... .......... 26% 49.6M 3s
#  23900K .......... .......... .......... .......... .......... 26%  162M 3s
#  23950K .......... .......... .......... .......... .......... 26% 98.9M 3s
#  24000K .......... .......... .......... .......... .......... 26%  202M 3s
#  24050K .......... .......... .......... .......... .......... 26%  277M 3s
#  24100K .......... .......... .......... .......... .......... 26% 9.50M 3s
#  24150K .......... .......... .......... .......... .......... 26%  229M 3s
#  24200K .......... .......... .......... .......... .......... 26%  189M 3s
#  24250K .......... .......... .......... .......... .......... 26%  176M 3s
#  24300K .......... .......... .......... .......... .......... 27%  187M 3s
#  24350K .......... .......... .......... .......... .......... 27% 33.3M 3s
#  24400K .......... .......... .......... .......... .......... 27%  144M 3s
#  24450K .......... .......... .......... .......... .......... 27%  266M 3s
#  24500K .......... .......... .......... .......... .......... 27%  240M 3s
#  24550K .......... .......... .......... .......... .......... 27%  241M 3s
#  24600K .......... .......... .......... .......... .......... 27%  189M 3s
#  24650K .......... .......... .......... .......... .......... 27%  278M 3s
#  24700K .......... .......... .......... .......... .......... 27%  277M 3s
#  24750K .......... .......... .......... .......... .......... 27% 2.83M 3s
#  24800K .......... .......... .......... .......... .......... 27% 9.98M 3s
#  24850K .......... .......... .......... .......... .......... 27% 5.24M 3s
#  24900K .......... .......... .......... .......... .......... 27%  235M 3s
#  24950K .......... .......... .......... .......... .......... 27%  265M 3s
#  25000K .......... .......... .......... .......... .......... 27%  249M 3s
#  25050K .......... .......... .......... .......... .......... 27%  268M 3s
#  25100K .......... .......... .......... .......... .......... 27% 2.39M 3s
#  25150K .......... .......... .......... .......... .......... 27%  203M 3s
#  25200K .......... .......... .......... .......... .......... 28%  275M 3s
#  25250K .......... .......... .......... .......... .......... 28%  290M 3s
#  25300K .......... .......... .......... .......... .......... 28%  257M 3s
#  25350K .......... .......... .......... .......... .......... 28%  264M 3s
#  25400K .......... .......... .......... .......... .......... 28%  289M 3s
#  25450K .......... .......... .......... .......... .......... 28% 3.47M 3s
#  25500K .......... .......... .......... .......... .......... 28% 37.0M 3s
#  25550K .......... .......... .......... .......... .......... 28%  281M 3s
#  25600K .......... .......... .......... .......... .......... 28%  256M 3s
#  25650K .......... .......... .......... .......... .......... 28%  283M 3s
#  25700K .......... .......... .......... .......... .......... 28%  220M 3s
#  25750K .......... .......... .......... .......... .......... 28%  258M 3s
#  25800K .......... .......... .......... .......... .......... 28% 41.2M 3s
#  25850K .......... .......... .......... .......... .......... 28%  184M 3s
#  25900K .......... .......... .......... .......... .......... 28%  224M 3s
#  25950K .......... .......... .......... .......... .......... 28%  280M 3s
#  26000K .......... .......... .......... .......... .......... 28%  288M 3s
#  26050K .......... .......... .......... .......... .......... 28%  256M 3s
#  26100K .......... .......... .......... .......... .......... 29%  248M 3s
#  26150K .......... .......... .......... .......... .......... 29%  233M 3s
#  26200K .......... .......... .......... .......... .......... 29%  259M 3s
#  26250K .......... .......... .......... .......... .......... 29% 63.6M 3s
#  26300K .......... .......... .......... .......... .......... 29%  286M 3s
#  26350K .......... .......... .......... .......... .......... 29%  281M 3s
#  26400K .......... .......... .......... .......... .......... 29%  269M 3s
#  26450K .......... .......... .......... .......... .......... 29%  249M 3s
#  26500K .......... .......... .......... .......... .......... 29%  252M 3s
#  26550K .......... .......... .......... .......... .......... 29%  267M 3s
#  26600K .......... .......... .......... .......... .......... 29%  266M 3s
#  26650K .......... .......... .......... .......... .......... 29%  217M 3s
#  26700K .......... .......... .......... .......... .......... 29%  270M 3s
#  26750K .......... .......... .......... .......... .......... 29%  250M 3s
#  26800K .......... .......... .......... .......... .......... 29%  276M 3s
#  26850K .......... .......... .......... .......... .......... 29%  239M 3s
#  26900K .......... .......... .......... .......... .......... 29%  247M 3s
#  26950K .......... .......... .......... .......... .......... 29%  231M 3s
#  27000K .......... .......... .......... .......... .......... 30% 35.1M 3s
#  27050K .......... .......... .......... .......... .......... 30%  219M 3s
#  27100K .......... .......... .......... .......... .......... 30%  223M 3s
#  27150K .......... .......... .......... .......... .......... 30%  281M 3s
#  27200K .......... .......... .......... .......... .......... 30%  116M 3s
#  27250K .......... .......... .......... .......... .......... 30%  262M 3s
#  27300K .......... .......... .......... .......... .......... 30%  158M 3s
#  27350K .......... .......... .......... .......... .......... 30%  186M 3s
#  27400K .......... .......... .......... .......... .......... 30%  161M 3s
#  27450K .......... .......... .......... .......... .......... 30%  279M 3s
#  27500K .......... .......... .......... .......... .......... 30%  246M 3s
#  27550K .......... .......... .......... .......... .......... 30% 2.69M 3s
#  27600K .......... .......... .......... .......... .......... 30%  232M 3s
#  27650K .......... .......... .......... .......... .......... 30%  290M 3s
#  27700K .......... .......... .......... .......... .......... 30%  286M 3s
#  27750K .......... .......... .......... .......... .......... 30%  291M 3s
#  27800K .......... .......... .......... .......... .......... 30% 12.1M 3s
#  27850K .......... .......... .......... .......... .......... 30% 2.13M 3s
#  27900K .......... .......... .......... .......... .......... 31%  179M 3s
#  27950K .......... .......... .......... .......... .......... 31%  238M 3s
#  28000K .......... .......... .......... .......... .......... 31%  232M 3s
#  28050K .......... .......... .......... .......... .......... 31%  257M 3s
#  28100K .......... .......... .......... .......... .......... 31%  261M 3s
#  28150K .......... .......... .......... .......... .......... 31% 7.42M 3s
#  28200K .......... .......... .......... .......... .......... 31% 4.33M 3s
#  28250K .......... .......... .......... .......... .......... 31%  242M 3s
#  28300K .......... .......... .......... .......... .......... 31%  279M 3s
#  28350K .......... .......... .......... .......... .......... 31%  218M 3s
#  28400K .......... .......... .......... .......... .......... 31%  275M 3s
#  28450K .......... .......... .......... .......... .......... 31%  277M 3s
#  28500K .......... .......... .......... .......... .......... 31%  284M 3s
#  28550K .......... .......... .......... .......... .......... 31% 11.9M 3s
#  28600K .......... .......... .......... .......... .......... 31%  278M 3s
#  28650K .......... .......... .......... .......... .......... 31% 35.6M 3s
#  28700K .......... .......... .......... .......... .......... 31%  114M 3s
#  28750K .......... .......... .......... .......... .......... 31%  151M 3s
#  28800K .......... .......... .......... .......... .......... 32%  204M 3s
#  28850K .......... .......... .......... .......... .......... 32%  263M 3s
#  28900K .......... .......... .......... .......... .......... 32%  277M 3s
#  28950K .......... .......... .......... .......... .......... 32%  223M 3s
#  29000K .......... .......... .......... .......... .......... 32%  281M 3s
#  29050K .......... .......... .......... .......... .......... 32%  226M 3s
#  29100K .......... .......... .......... .......... .......... 32%  247M 3s
#  29150K .......... .......... .......... .......... .......... 32%  267M 3s
#  29200K .......... .......... .......... .......... .......... 32%  271M 3s
#  29250K .......... .......... .......... .......... .......... 32% 11.2M 3s
#  29300K .......... .......... .......... .......... .......... 32%  172M 3s
#  29350K .......... .......... .......... .......... .......... 32%  266M 3s
#  29400K .......... .......... .......... .......... .......... 32%  265M 3s
#  29450K .......... .......... .......... .......... .......... 32%  268M 3s
#  29500K .......... .......... .......... .......... .......... 32%  231M 3s
#  29550K .......... .......... .......... .......... .......... 32%  243M 3s
#  29600K .......... .......... .......... .......... .......... 32%  274M 3s
#  29650K .......... .......... .......... .......... .......... 32%  160M 3s
#  29700K .......... .......... .......... .......... .......... 33%  170M 3s
#  29750K .......... .......... .......... .......... .......... 33%  183M 3s
#  29800K .......... .......... .......... .......... .......... 33%  281M 3s
#  29850K .......... .......... .......... .......... .......... 33%  272M 3s
#  29900K .......... .......... .......... .......... .......... 33%  255M 3s
#  29950K .......... .......... .......... .......... .......... 33%  251M 3s
#  30000K .......... .......... .......... .......... .......... 33%  268M 3s
#  30050K .......... .......... .......... .......... .......... 33%  223M 3s
#  30100K .......... .......... .......... .......... .......... 33%  241M 3s
#  30150K .......... .......... .......... .......... .......... 33%  270M 3s
#  30200K .......... .......... .......... .......... .......... 33%  251M 3s
#  30250K .......... .......... .......... .......... .......... 33%  244M 3s
#  30300K .......... .......... .......... .......... .......... 33%  266M 3s
#  30350K .......... .......... .......... .......... .......... 33%  280M 3s
#  30400K .......... .......... .......... .......... .......... 33%  244M 3s
#  30450K .......... .......... .......... .......... .......... 33%  218M 3s
#  30500K .......... .......... .......... .......... .......... 33% 3.10M 3s
#  30550K .......... .......... .......... .......... .......... 33%  203M 3s
#  30600K .......... .......... .......... .......... .......... 34%  282M 3s
#  30650K .......... .......... .......... .......... .......... 34%  255M 3s
#  30700K .......... .......... .......... .......... .......... 34% 11.3M 3s
#  30750K .......... .......... .......... .......... .......... 34%  284M 3s
#  30800K .......... .......... .......... .......... .......... 34%  234M 3s
#  30850K .......... .......... .......... .......... .......... 34%  218M 3s
#  30900K .......... .......... .......... .......... .......... 34% 2.21M 3s
#  30950K .......... .......... .......... .......... .......... 34%  144M 3s
#  31000K .......... .......... .......... .......... .......... 34% 6.68M 3s
#  31050K .......... .......... .......... .......... .......... 34%  242M 3s
#  31100K .......... .......... .......... .......... .......... 34%  272M 3s
# ...
#  79650K .......... .......... .......... .......... .......... 88%  349M 0s
#  79700K .......... .......... .......... .......... .......... 88%  148M 0s
#  79750K .......... .......... .......... .......... .......... 88%  258M 0s
#  79800K .......... .......... .......... .......... .......... 88%  320M 0s
#  79850K .......... .......... .......... .......... .......... 88%  301M 0s
#  79900K .......... .......... .......... .......... .......... 88%  697K 0s
#  79950K .......... .......... .......... .......... .......... 88%  187M 0s
#  80000K .......... .......... .......... .......... .......... 88%  251M 0s
#  80050K .......... .......... .......... .......... .......... 88%  297M 0s
#  80100K .......... .......... .......... .......... .......... 89%  293M 0s
#  80150K .......... .......... .......... .......... .......... 89%  215M 0s
#  80200K .......... .......... .......... .......... .......... 89%  298M 0s
#  80250K .......... .......... .......... .......... .......... 89%  294M 0s
#  80300K .......... .......... .......... .......... .......... 89%  333M 0s
#  80350K .......... .......... .......... .......... .......... 89%  274M 0s
#  80400K .......... .......... .......... .......... .......... 89%  343M 0s
#  80450K .......... .......... .......... .......... .......... 89%  330M 0s
#  80500K .......... .......... .......... .......... .......... 89%  302M 0s
#  80550K .......... .......... .......... .......... .......... 89%  310M 0s
#  80600K .......... .......... .......... .......... .......... 89%  340M 0s
#  80650K .......... .......... .......... .......... .......... 89%  314M 0s
#  80700K .......... .......... .......... .......... .......... 89%  331M 0s
#  80750K .......... .......... .......... .......... .......... 89%  280M 0s
#  80800K .......... .......... .......... .......... .......... 89%  334M 0s
#  80850K .......... .......... .......... .......... .......... 89%  333M 0s
#  80900K .......... .......... .......... .......... .......... 89%  302M 0s
#  80950K .......... .......... .......... .......... .......... 89%  337M 0s
#  81000K .......... .......... .......... .......... .......... 90%  335M 0s
#  81050K .......... .......... .......... .......... .......... 90%  328M 0s
#  81100K .......... .......... .......... .......... .......... 90%  262M 0s
#  81150K .......... .......... .......... .......... .......... 90%  319M 0s
#  81200K .......... .......... .......... .......... .......... 90%  355M 0s
#  81250K .......... .......... .......... .......... .......... 90%  327M 0s
#  81300K .......... .......... .......... .......... .......... 90%  295M 0s
#  81350K .......... .......... .......... .......... .......... 90%  335M 0s
#  81400K .......... .......... .......... .......... .......... 90%  325M 0s
#  81450K .......... .......... .......... .......... .......... 90%  342M 0s
#  81500K .......... .......... .......... .......... .......... 90%  281M 0s
#  81550K .......... .......... .......... .......... .......... 90%  342M 0s
#  81600K .......... .......... .......... .......... .......... 90%  344M 0s
#  81650K .......... .......... .......... .......... .......... 90%  343M 0s
#  81700K .......... .......... .......... .......... .......... 90% 80.4M 0s
#  81750K .......... .......... .......... .......... .......... 90%  308M 0s
#  81800K .......... .......... .......... .......... .......... 90%  279M 0s
#  81850K .......... .......... .......... .......... .......... 90%  226M 0s
#  81900K .......... .......... .......... .......... .......... 91%  206M 0s
#  81950K .......... .......... .......... .......... .......... 91%  207M 0s
#  82000K .......... .......... .......... .......... .......... 91%  250M 0s
#  82050K .......... .......... .......... .......... .......... 91%  186M 0s
#  82100K .......... .......... .......... .......... .......... 91%  228M 0s
#  82150K .......... .......... .......... .......... .......... 91%  229M 0s
#  82200K .......... .......... .......... .......... .......... 91%  207M 0s
#  82250K .......... .......... .......... .......... .......... 91%  184M 0s
#  82300K .......... .......... .......... .......... .......... 91%  206M 0s
#  82350K .......... .......... .......... .......... .......... 91%  217M 0s
#  82400K .......... .......... .......... .......... .......... 91%  220M 0s
#  82450K .......... .......... .......... .......... .......... 91%  302M 0s
#  82500K .......... .......... .......... .......... .......... 91%  354M 0s
#  82550K .......... .......... .......... .......... .......... 91%  348M 0s
#  82600K .......... .......... .......... .......... .......... 91%  330M 0s
#  82650K .......... .......... .......... .......... .......... 91%  286M 0s
#  82700K .......... .......... .......... .......... .......... 91%  343M 0s
#  82750K .......... .......... .......... .......... .......... 91%  351M 0s
#  82800K .......... .......... .......... .......... .......... 92% 1.39M 0s
#  82850K .......... .......... .......... .......... .......... 92%  245M 0s
#  82900K .......... .......... .......... .......... .......... 92% 1.67M 0s
#  82950K .......... .......... .......... .......... .......... 92%  232M 0s
#  83000K .......... .......... .......... .......... .......... 92%  227M 0s
#  83050K .......... .......... .......... .......... .......... 92%  298M 0s
#  83100K .......... .......... .......... .......... .......... 92% 8.89M 0s
#  83150K .......... .......... .......... .......... .......... 92%  267M 0s
#  83200K .......... .......... .......... .......... .......... 92%  240M 0s
#  83250K .......... .......... .......... .......... .......... 92%  310M 0s
#  83300K .......... .......... .......... .......... .......... 92%  322M 0s
#  83350K .......... .......... .......... .......... .......... 92%  341M 0s
#  83400K .......... .......... .......... .......... .......... 92%  256M 0s
#  83450K .......... .......... .......... .......... .......... 92%  333M 0s
#  83500K .......... .......... .......... .......... .......... 92%  339M 0s
#  83550K .......... .......... .......... .......... .......... 92%  340M 0s
#  83600K .......... .......... .......... .......... .......... 92%  150M 0s
#  83650K .......... .......... .......... .......... .......... 92%  284M 0s
#  83700K .......... .......... .......... .......... .......... 93%  230M 0s
#  83750K .......... .......... .......... .......... .......... 93%  350M 0s
#  83800K .......... .......... .......... .......... .......... 93%  266M 0s
#  83850K .......... .......... .......... .......... .......... 93% 13.6M 0s
#  83900K .......... .......... .......... .......... .......... 93%  237M 0s
#  83950K .......... .......... .......... .......... .......... 93%  235M 0s
#  84000K .......... .......... .......... .......... .......... 93%  275M 0s
#  84050K .......... .......... .......... .......... .......... 93%  314M 0s
#  84100K .......... .......... .......... .......... .......... 93%  298M 0s
#  84150K .......... .......... .......... .......... .......... 93%  286M 0s
#  84200K .......... .......... .......... .......... .......... 93%  325M 0s
#  84250K .......... .......... .......... .......... .......... 93%  344M 0s
#  84300K .......... .......... .......... .......... .......... 93%  344M 0s
#  84350K .......... .......... .......... .......... .......... 93%  303M 0s
#  84400K .......... .......... .......... .......... .......... 93%  287M 0s
#  84450K .......... .......... .......... .......... .......... 93%  341M 0s
#  84500K .......... .......... .......... .......... .......... 93%  334M 0s
#  84550K .......... .......... .......... .......... .......... 93%  284M 0s
#  84600K .......... .......... .......... .......... .......... 94%  340M 0s
#  84650K .......... .......... .......... .......... .......... 94%  356M 0s
#  84700K .......... .......... .......... .......... .......... 94%  344M 0s
#  84750K .......... .......... .......... .......... .......... 94%  257M 0s
#  84800K .......... .......... .......... .......... .......... 94%  316M 0s
#  84850K .......... .......... .......... .......... .......... 94%  317M 0s
#  84900K .......... .......... .......... .......... .......... 94%  264M 0s
#  84950K .......... .......... .......... .......... .......... 94%  333M 0s
#  85000K .......... .......... .......... .......... .......... 94%  316M 0s
#  85050K .......... .......... .......... .......... .......... 94%  309M 0s
#  85100K .......... .......... .......... .......... .......... 94%  310M 0s
#  85150K .......... .......... .......... .......... .......... 94%  311M 0s
#  85200K .......... .......... .......... .......... .......... 94%  335M 0s
#  85250K .......... .......... .......... .......... .......... 94%  323M 0s
#  85300K .......... .......... .......... .......... .......... 94%  139M 0s
#  85350K .......... .......... .......... .......... .......... 94%  351M 0s
#  85400K .......... .......... .......... .......... .......... 94%  355M 0s
#  85450K .......... .......... .......... .......... .......... 94%  349M 0s
#  85500K .......... .......... .......... .......... .......... 95% 1.43M 0s
#  85550K .......... .......... .......... .......... .......... 95%  305M 0s
#  85600K .......... .......... .......... .......... .......... 95%  341M 0s
#  85650K .......... .......... .......... .......... .......... 95% 1.66M 0s
#  85700K .......... .......... .......... .......... .......... 95%  200M 0s
#  85750K .......... .......... .......... .......... .......... 95%  297M 0s
#  85800K .......... .......... .......... .......... .......... 95%  348M 0s
#  85850K .......... .......... .......... .......... .......... 95%  349M 0s
#  85900K .......... .......... .......... .......... .......... 95%  299M 0s
#  85950K .......... .......... .......... .......... .......... 95%  352M 0s
#  86000K .......... .......... .......... .......... .......... 95%  345M 0s
#  86050K .......... .......... .......... .......... .......... 95% 10.2M 0s
#  86100K .......... .......... .......... .......... .......... 95%  271M 0s
#  86150K .......... .......... .......... .......... .......... 95%  287M 0s
#  86200K .......... .......... .......... .......... .......... 95%  330M 0s
#  86250K .......... .......... .......... .......... .......... 95%  220M 0s
#  86300K .......... .......... .......... .......... .......... 95%  295M 0s
#  86350K .......... .......... .......... .......... .......... 95%  348M 0s
#  86400K .......... .......... .......... .......... .......... 96%  354M 0s
#  86450K .......... .......... .......... .......... .......... 96%  289M 0s
#  86500K .......... .......... .......... .......... .......... 96%  341M 0s
#  86550K .......... .......... .......... .......... .......... 96%  148M 0s
#  86600K .......... .......... .......... .......... .......... 96%  327M 0s
#  86650K .......... .......... .......... .......... .......... 96%  308M 0s
#  86700K .......... .......... .......... .......... .......... 96%  353M 0s
#  86750K .......... .......... .......... .......... .......... 96%  357M 0s
#  86800K .......... .......... .......... .......... .......... 96% 13.3M 0s
#  86850K .......... .......... .......... .......... .......... 96%  218M 0s
#  86900K .......... .......... .......... .......... .......... 96%  296M 0s
#  86950K .......... .......... .......... .......... .......... 96%  337M 0s
#  87000K .......... .......... .......... .......... .......... 96%  306M 0s
#  87050K .......... .......... .......... .......... .......... 96%  304M 0s
#  87100K .......... .......... .......... .......... .......... 96%  343M 0s
#  87150K .......... .......... .......... .......... .......... 96%  329M 0s
#  87200K .......... .......... .......... .......... .......... 96%  287M 0s
#  87250K .......... .......... .......... .......... .......... 96%  353M 0s
#  87300K .......... .......... .......... .......... .......... 97%  343M 0s
#  87350K .......... .......... .......... .......... .......... 97%  345M 0s
#  87400K .......... .......... .......... .......... .......... 97%  319M 0s
#  87450K .......... .......... .......... .......... .......... 97%  359M 0s
#  87500K .......... .......... .......... .......... .......... 97%  352M 0s
#  87550K .......... .......... .......... .......... .......... 97%  346M 0s
#  87600K .......... .......... .......... .......... .......... 97%  297M 0s
#  87650K .......... .......... .......... .......... .......... 97%  357M 0s
#  87700K .......... .......... .......... .......... .......... 97%  144M 0s
#  87750K .......... .......... .......... .......... .......... 97%  327M 0s
#  87800K .......... .......... .......... .......... .......... 97%  293M 0s
#  87850K .......... .......... .......... .......... .......... 97%  357M 0s
#  87900K .......... .......... .......... .......... .......... 97%  349M 0s
#  87950K .......... .......... .......... .......... .......... 97%  302M 0s
#  88000K .......... .......... .......... .......... .......... 97%  338M 0s
#  88050K .......... .......... .......... .......... .......... 97% 1.38M 0s
#  88100K .......... .......... .......... .......... .......... 97%  196M 0s
#  88150K .......... .......... .......... .......... .......... 97%  214M 0s
#  88200K .......... .......... .......... .......... .......... 98%  282M 0s
#  88250K .......... .......... .......... .......... .......... 98%  283M 0s
#  88300K .......... .......... .......... .......... .......... 98%  282M 0s
#  88350K .......... .......... .......... .......... .......... 98%  265M 0s
#  88400K .......... .......... .......... .......... .......... 98%  340M 0s
#  88450K .......... .......... .......... .......... .......... 98%  289M 0s
#  88500K .......... .......... .......... .......... .......... 98%  300M 0s
#  88550K .......... .......... .......... .......... .......... 98% 1.75M 0s
#  88600K .......... .......... .......... .......... .......... 98%  190M 0s
#  88650K .......... .......... .......... .......... .......... 98%  225M 0s
#  88700K .......... .......... .......... .......... .......... 98%  218M 0s
#  88750K .......... .......... .......... .......... .......... 98%  219M 0s
#  88800K .......... .......... .......... .......... .......... 98% 9.85M 0s
#  88850K .......... .......... .......... .......... .......... 98%  230M 0s
#  88900K .......... .......... .......... .......... .......... 98%  259M 0s
#  88950K .......... .......... .......... .......... .......... 98%  274M 0s
#  89000K .......... .......... .......... .......... .......... 98%  350M 0s
#  89050K .......... .......... .......... .......... .......... 98%  338M 0s
#  89100K .......... .......... .......... .......... .......... 99%  256M 0s
#  89150K .......... .......... .......... .......... .......... 99%  349M 0s
#  89200K .......... .......... .......... .......... .......... 99%  352M 0s
#  89250K .......... .......... .......... .......... .......... 99%  349M 0s
#  89300K .......... .......... .......... .......... .......... 99%  318M 0s
#  89350K .......... .......... .......... .......... .......... 99%  101M 0s
#  89400K .......... .......... .......... .......... .......... 99%  300M 0s
#  89450K .......... .......... .......... .......... .......... 99%  341M 0s
#  89500K .......... .......... .......... .......... .......... 99%  283M 0s
#  89550K .......... .......... .......... .......... .......... 99%  355M 0s
#  89600K .......... .......... .......... .......... .......... 99%  306M 0s
#  89650K .......... .......... .......... .......... .......... 99%  331M 0s
#  89700K .......... .......... .......... .......... .......... 99%  315M 0s
#  89750K .......... .......... .......... .......... .......... 99%  352M 0s
#  89800K .......... .......... .......... .......... .......... 99% 16.9M 0s
#  89850K .......... .......... .......... .......... .......... 99%  268M 0s
#  89900K .......... .......... .......... .......... .......... 99%  246M 0s
#  89950K .......... .......... .......... .......... .......... 99%  343M 0s
#  90000K .......... ......                                     100%  358M=3.3s
#
# 2025-02-17 15:42:03 (26.4 MB/s) - ‘/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_1_frags.tsv.gz’ saved [92176503/92176503]

# %%
# Get the fragments files for individual samples
# Note: the fragments files should have 4 columns: chromosome, start, end, and barcode. 
# Barcode should just be sample name, which means all fragments in the same fragments file have the same barcode.
frag_files = os.listdir(frag_dir)
frag_files = [i for i in frag_files if re.search("frags.tsv.gz", i) is not None]
frag_files = sorted([os.path.join(frag_dir, i) for i in frag_files])
samples = ["_".join(re.split("[/_\\.]", i)[11:13]) for i in frag_files]
samples
# Out:
# ['Bcell_0', 'Bcell_1', 'Monocyte_0', 'Monocyte_1', 'Tcell_0', 'Tcell_1']

# %% [markdown]
# ## Create scprinter & preprocessing

# %%
printer = scp.load_printer(os.path.join(work_dir, 'PBMC_bulkATAC_scprinter.h5ad'), scp.genome.hg38)

# %%
printer = scp.pp.import_fragments(
                        path_to_frags=frag_files,
                        barcodes=[None] * len(frag_files), # This loads individual fragments files and combine them
                        savename=os.path.join(work_dir, 'PBMC_bulkATAC_scprinter.h5ad'),
                        genome=scp.genome.hg38,
                        min_num_fragments=1000, min_tsse=7,
                        sorted_by_barcode=False, 
                        low_memory=False,
                        )
# Out:
# Multiple fragments files detected, it is suggested to provide sample names to avoid barcode collision
# You are now using the beta auto_detect_shift function, this overwrites the plus_shift and minus_shift you provided
# If you believe the auto_detect_shift is wrong, please set auto_detect_shift=False
# Importing fragments:   0%|          | 0/6 [00:00<?, ?it/s]
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.0006028337389735553, shift detected
# Minimum MSE is 0.0005621760488880932, shift detected
# detected plus_shift and minus_shift are 4 -5 for /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_0_frags.tsv.gz
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.0005579577064850174, shift detected
# Minimum MSE is 0.0005716092680446101, shift detected
# detected plus_shift and minus_shift are 4 -5 for /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_1_frags.tsv.gz
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.00012641679680961733, shift detected
# Minimum MSE is 0.0001328003138130926, shift detected
# detected plus_shift and minus_shift are 4 -5 for /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_0_frags.tsv.gz
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.00014547498808930152, shift detected
# Minimum MSE is 0.0001298167647820722, shift detected
# detected plus_shift and minus_shift are 4 -5 for /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_1_frags.tsv.gz
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.0009658254868701564, shift detected
# Minimum MSE is 0.0009298322715241607, shift detected
# detected plus_shift and minus_shift are 4 -5 for /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_0_frags.tsv.gz
# Detecting the shift in the paired end fragments file
# If you think the above message is wrong, please check the input file format
# Minimum MSE is 0.0009286720531134285, shift detected
# Minimum MSE is 0.000924783575692764, shift detected
# detected plus_shift and minus_shift are 4 -5 for /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_1_frags.tsv.gz
#   0%|          | 0/6 [00:00<?, ?it/s]
# start transferring insertions

# %%
print (printer.insertion_file.obs_names[:])
# Out:
# ['Bcell_0', 'Bcell_1', 'Monocyte_0', 'Monocyte_1', 'Tcell_0', 'Tcell_1']

# %%
# Rename barcodes to sample IDs if needed. 
printer.insertion_file.obs_names = samples

# %% [markdown]
# ## Call peaks on the fragments in a preset for training seq2PRINT model

# %%
# Call peaks, this set of peaks are recommended to train seq2PRINT model
scp.pp.call_peaks(printer=printer,
                  frag_file=frag_files,
                  cell_grouping=[None], # here we call peaks on the cells that are included in the final analyses
                  group_names=['all'],
                  preset='seq2PRINT',
                  overwrite=False)

# Fetched the cleaned peaks, save, it will be used in the next step
cleaned_peaks = pd.DataFrame(printer.uns["peak_calling"]['all_cleaned'][:])
cleaned_peaks.to_csv(f'{work_dir}/seq2print_cleaned_narrowPeak.bed', 
                     sep='\t', header=False, index=False)
# Out:
# INFO  @ Mon, 17 Feb 2025 16:00:12:
# # Command line: callpeak --nomodel -t /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_0_frags.tsv.gz /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_1_frags.tsv.gz /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_0_frags.tsv.gz /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_1_frags.tsv.gz /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_0_frags.tsv.gz /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_1_frags.tsv.gz --outdir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2 -n all -f BEDPE --nolambda --keep-dup all --call-summits --nomodel -B --SPMR --shift 75 --extsize 150 -p 0.01
# # ARGUMENTS LIST:
# # name = all
# # format = BEDPE
# # ChIP-seq file = ['/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_0_frags.tsv.gz', '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_1_frags.tsv.gz', '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_0_frags.tsv.gz', '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_1_frags.tsv.gz', '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_0_frags.tsv.gz', '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_1_frags.tsv.gz']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # pvalue cutoff = 1.00e-02
# # qvalue will not be calculated and reported as -1 in the final output.
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is on
# # Searching for subpeak summits is on
# # MACS will save fragment pileup signal per million reads
#
# INFO  @ Mon, 17 Feb 2025 16:00:12: #1 read fragment files...
# INFO  @ Mon, 17 Feb 2025 16:00:12: #1 read treatment fragments...
# INFO  @ Mon, 17 Feb 2025 16:00:13:  1000000
# INFO  @ Mon, 17 Feb 2025 16:00:14:  2000000
# INFO  @ Mon, 17 Feb 2025 16:00:15:  3000000
# INFO  @ Mon, 17 Feb 2025 16:00:16:  4000000
# INFO  @ Mon, 17 Feb 2025 16:00:17:  5000000
# INFO  @ Mon, 17 Feb 2025 16:00:18:  6000000
# INFO  @ Mon, 17 Feb 2025 16:00:19:  7000000
# INFO  @ Mon, 17 Feb 2025 16:00:20:  8000000
# INFO  @ Mon, 17 Feb 2025 16:00:21:  9000000
# INFO  @ Mon, 17 Feb 2025 16:00:22:  10000000
# INFO  @ Mon, 17 Feb 2025 16:00:22:  1000000
# INFO  @ Mon, 17 Feb 2025 16:00:23:  2000000
# INFO  @ Mon, 17 Feb 2025 16:00:24:  3000000
# INFO  @ Mon, 17 Feb 2025 16:00:25:  4000000
# INFO  @ Mon, 17 Feb 2025 16:00:26:  5000000
# INFO  @ Mon, 17 Feb 2025 16:00:27:  6000000
# INFO  @ Mon, 17 Feb 2025 16:00:28:  7000000
# INFO  @ Mon, 17 Feb 2025 16:00:29:  8000000
# INFO  @ Mon, 17 Feb 2025 16:00:30:  9000000
# INFO  @ Mon, 17 Feb 2025 16:00:31:  10000000
# INFO  @ Mon, 17 Feb 2025 16:00:32:  1000000
# INFO  @ Mon, 17 Feb 2025 16:00:33:  2000000
# INFO  @ Mon, 17 Feb 2025 16:00:34:  3000000
# INFO  @ Mon, 17 Feb 2025 16:00:34:  4000000
# INFO  @ Mon, 17 Feb 2025 16:00:35:  5000000
# INFO  @ Mon, 17 Feb 2025 16:00:36:  6000000
# INFO  @ Mon, 17 Feb 2025 16:00:37:  7000000
# INFO  @ Mon, 17 Feb 2025 16:00:38:  8000000
# INFO  @ Mon, 17 Feb 2025 16:00:39:  9000000
# INFO  @ Mon, 17 Feb 2025 16:00:40:  10000000
# INFO  @ Mon, 17 Feb 2025 16:00:41:  1000000
# INFO  @ Mon, 17 Feb 2025 16:00:42:  2000000
# INFO  @ Mon, 17 Feb 2025 16:00:43:  3000000
# INFO  @ Mon, 17 Feb 2025 16:00:44:  4000000
# INFO  @ Mon, 17 Feb 2025 16:00:45:  5000000
# INFO  @ Mon, 17 Feb 2025 16:00:46:  6000000
# INFO  @ Mon, 17 Feb 2025 16:00:47:  7000000
# INFO  @ Mon, 17 Feb 2025 16:00:47:  8000000
# INFO  @ Mon, 17 Feb 2025 16:00:48:  9000000
# INFO  @ Mon, 17 Feb 2025 16:00:49:  10000000
# INFO  @ Mon, 17 Feb 2025 16:00:50:  1000000
# INFO  @ Mon, 17 Feb 2025 16:00:51:  2000000
# INFO  @ Mon, 17 Feb 2025 16:00:52:  3000000
# INFO  @ Mon, 17 Feb 2025 16:00:53:  4000000
# INFO  @ Mon, 17 Feb 2025 16:00:54:  5000000
# INFO  @ Mon, 17 Feb 2025 16:00:55:  6000000
# INFO  @ Mon, 17 Feb 2025 16:00:56:  7000000
# INFO  @ Mon, 17 Feb 2025 16:00:57:  8000000
# INFO  @ Mon, 17 Feb 2025 16:00:58:  9000000
# INFO  @ Mon, 17 Feb 2025 16:00:58:  10000000
# INFO  @ Mon, 17 Feb 2025 16:00:59:  1000000
# INFO  @ Mon, 17 Feb 2025 16:01:00:  2000000
# INFO  @ Mon, 17 Feb 2025 16:01:01:  3000000
# INFO  @ Mon, 17 Feb 2025 16:01:02:  4000000
# INFO  @ Mon, 17 Feb 2025 16:01:03:  5000000
# INFO  @ Mon, 17 Feb 2025 16:01:04:  6000000
# INFO  @ Mon, 17 Feb 2025 16:01:05:  7000000
# INFO  @ Mon, 17 Feb 2025 16:01:06:  8000000
# INFO  @ Mon, 17 Feb 2025 16:01:07:  9000000
# INFO  @ Mon, 17 Feb 2025 16:01:08:  10000000
# INFO  @ Mon, 17 Feb 2025 16:01:47: #1 mean fragment size is determined as 153.3 bp from treatment
# INFO  @ Mon, 17 Feb 2025 16:01:47: #1 fragment size = 153.3
# INFO  @ Mon, 17 Feb 2025 16:01:47: #1  total fragments in treatment: 60000000
# INFO  @ Mon, 17 Feb 2025 16:01:47: #1 finished!
# INFO  @ Mon, 17 Feb 2025 16:01:47: #2 Build Peak Model...
# INFO  @ Mon, 17 Feb 2025 16:01:47: #2 Skipped...
# INFO  @ Mon, 17 Feb 2025 16:01:47: #3 Call peaks...
# INFO  @ Mon, 17 Feb 2025 16:01:47: # local lambda is disabled!
# INFO  @ Mon, 17 Feb 2025 16:01:47: #3 !!!! DYNAMIC LAMBDA IS DISABLED !!!!
# INFO  @ Mon, 17 Feb 2025 16:01:47: #3 Going to call summits inside each peak ...
# INFO  @ Mon, 17 Feb 2025 16:01:47: #3 Call peaks with given -log10pvalue cutoff: 2.00000 ...
# INFO  @ Mon, 17 Feb 2025 16:01:47: #3 Pre-compute pvalue-qvalue table...
# INFO  @ Mon, 17 Feb 2025 16:02:00: #3 In the peak calling step, the following will be performed simultaneously:
# INFO  @ Mon, 17 Feb 2025 16:02:00: #3   Write bedGraph files for treatment pileup (after scaling if necessary)... all_treat_pileup.bdg
# INFO  @ Mon, 17 Feb 2025 16:02:00: #3   Write bedGraph files for control lambda (after scaling if necessary)... all_control_lambda.bdg
# INFO  @ Mon, 17 Feb 2025 16:02:00: #3   --SPMR is requested, so pileup will be normalized by sequencing depth in million reads.
# INFO  @ Mon, 17 Feb 2025 16:02:00: #3 Call peaks for each chromosome...
# INFO  @ Mon, 17 Feb 2025 16:03:17: #4 Write output xls file... /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2/all_peaks.xls
# INFO  @ Mon, 17 Feb 2025 16:03:18: #4 Write peak in narrowPeak format file... /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2/all_peaks.narrowPeak
# INFO  @ Mon, 17 Feb 2025 16:03:19: #4 Write summits bed file... /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2/all_summits.bed
# INFO  @ Mon, 17 Feb 2025 16:03:19: Done!
# Reading in peak summit file(s):
# NOTE: Assuming all start coordinates are 0-based ..
#
# Padding peak summits by: 500 bp on either side for
# Removing peaks overlapping with blacklisted regions and out of bound peaks based on chromosome sizes ..
#
# Filtering overlapping peaks based on peak summit score ..
# round: 1 299137 peaks unresolved 295927 peaks selected
# round: 2 146 peaks unresolved 142 peaks selected
# finish clearing
# finish sorting
# finished summary

# %%
# Call peaks using chromvar preset, this set of peak are recommended to be use as cell x peak for scATAC-seq data, or analysis
scp.pp.call_peaks(printer=printer,
                  frag_file=frag_files,
                  cell_grouping=[None], # here we call peaks on the cells that are included in the final analyses
                  group_names=['chromvar_all'],
                  preset='chromvar',
                  overwrite=False)

# Fetched the cleaned peaks, save, it will be used in the next step
cleaned_peaks = pd.DataFrame(printer.uns["peak_calling"]['chromvar_all_cleaned'][:])
cleaned_peaks.to_csv(f'{work_dir}/regions.bed', 
                     sep='\t', header=False, index=False)
# Out:
# INFO  @ Mon, 17 Feb 2025 16:03:42:
# # Command line: callpeak --nomodel -t /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_0_frags.tsv.gz /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_1_frags.tsv.gz /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_0_frags.tsv.gz /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_1_frags.tsv.gz /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_0_frags.tsv.gz /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_1_frags.tsv.gz --outdir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2 -n chromvar_all -f BEDPE --nolambda --keep-dup all --call-summits --nomodel -B --SPMR --shift 75 --extsize 150 -q 0.01
# # ARGUMENTS LIST:
# # name = chromvar_all
# # format = BEDPE
# # ChIP-seq file = ['/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_0_frags.tsv.gz', '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Bcell_1_frags.tsv.gz', '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_0_frags.tsv.gz', '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Monocyte_1_frags.tsv.gz', '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_0_frags.tsv.gz', '/ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//fragments/Tcell_1_frags.tsv.gz']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 1.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is on
# # Searching for subpeak summits is on
# # MACS will save fragment pileup signal per million reads
#
# INFO  @ Mon, 17 Feb 2025 16:03:42: #1 read fragment files...
# INFO  @ Mon, 17 Feb 2025 16:03:42: #1 read treatment fragments...
# INFO  @ Mon, 17 Feb 2025 16:03:43:  1000000
# INFO  @ Mon, 17 Feb 2025 16:03:44:  2000000
# INFO  @ Mon, 17 Feb 2025 16:03:45:  3000000
# INFO  @ Mon, 17 Feb 2025 16:03:46:  4000000
# INFO  @ Mon, 17 Feb 2025 16:03:47:  5000000
# INFO  @ Mon, 17 Feb 2025 16:03:48:  6000000
# INFO  @ Mon, 17 Feb 2025 16:03:49:  7000000
# INFO  @ Mon, 17 Feb 2025 16:03:51:  8000000
# INFO  @ Mon, 17 Feb 2025 16:03:52:  9000000
# INFO  @ Mon, 17 Feb 2025 16:03:53:  10000000
# INFO  @ Mon, 17 Feb 2025 16:03:54:  1000000
# INFO  @ Mon, 17 Feb 2025 16:03:55:  2000000
# INFO  @ Mon, 17 Feb 2025 16:03:56:  3000000
# INFO  @ Mon, 17 Feb 2025 16:03:57:  4000000
# INFO  @ Mon, 17 Feb 2025 16:03:58:  5000000
# INFO  @ Mon, 17 Feb 2025 16:03:59:  6000000
# INFO  @ Mon, 17 Feb 2025 16:04:00:  7000000
# INFO  @ Mon, 17 Feb 2025 16:04:01:  8000000
# INFO  @ Mon, 17 Feb 2025 16:04:02:  9000000
# INFO  @ Mon, 17 Feb 2025 16:04:03:  10000000
# INFO  @ Mon, 17 Feb 2025 16:04:05:  1000000
# INFO  @ Mon, 17 Feb 2025 16:04:06:  2000000
# INFO  @ Mon, 17 Feb 2025 16:04:07:  3000000
# INFO  @ Mon, 17 Feb 2025 16:04:08:  4000000
# INFO  @ Mon, 17 Feb 2025 16:04:09:  5000000
# INFO  @ Mon, 17 Feb 2025 16:04:10:  6000000
# INFO  @ Mon, 17 Feb 2025 16:04:11:  7000000
# INFO  @ Mon, 17 Feb 2025 16:04:12:  8000000
# INFO  @ Mon, 17 Feb 2025 16:04:13:  9000000
# INFO  @ Mon, 17 Feb 2025 16:04:14:  10000000
# INFO  @ Mon, 17 Feb 2025 16:04:15:  1000000
# INFO  @ Mon, 17 Feb 2025 16:04:16:  2000000
# INFO  @ Mon, 17 Feb 2025 16:04:17:  3000000
# INFO  @ Mon, 17 Feb 2025 16:04:19:  4000000
# INFO  @ Mon, 17 Feb 2025 16:04:20:  5000000
# INFO  @ Mon, 17 Feb 2025 16:04:21:  6000000
# INFO  @ Mon, 17 Feb 2025 16:04:22:  7000000
# INFO  @ Mon, 17 Feb 2025 16:04:23:  8000000
# INFO  @ Mon, 17 Feb 2025 16:04:24:  9000000
# INFO  @ Mon, 17 Feb 2025 16:04:25:  10000000
# INFO  @ Mon, 17 Feb 2025 16:04:26:  1000000
# INFO  @ Mon, 17 Feb 2025 16:04:27:  2000000
# INFO  @ Mon, 17 Feb 2025 16:04:28:  3000000
# INFO  @ Mon, 17 Feb 2025 16:04:29:  4000000
# INFO  @ Mon, 17 Feb 2025 16:04:30:  5000000
# INFO  @ Mon, 17 Feb 2025 16:04:31:  6000000
# INFO  @ Mon, 17 Feb 2025 16:04:33:  7000000
# INFO  @ Mon, 17 Feb 2025 16:04:34:  8000000
# INFO  @ Mon, 17 Feb 2025 16:04:35:  9000000
# INFO  @ Mon, 17 Feb 2025 16:04:36:  10000000
# INFO  @ Mon, 17 Feb 2025 16:04:37:  1000000
# INFO  @ Mon, 17 Feb 2025 16:04:38:  2000000
# INFO  @ Mon, 17 Feb 2025 16:04:39:  3000000
# INFO  @ Mon, 17 Feb 2025 16:04:40:  4000000
# INFO  @ Mon, 17 Feb 2025 16:04:41:  5000000
# INFO  @ Mon, 17 Feb 2025 16:04:42:  6000000
# INFO  @ Mon, 17 Feb 2025 16:04:43:  7000000
# INFO  @ Mon, 17 Feb 2025 16:04:44:  8000000
# INFO  @ Mon, 17 Feb 2025 16:04:45:  9000000
# INFO  @ Mon, 17 Feb 2025 16:04:47:  10000000
# INFO  @ Mon, 17 Feb 2025 16:05:30: #1 mean fragment size is determined as 153.3 bp from treatment
# INFO  @ Mon, 17 Feb 2025 16:05:30: #1 fragment size = 153.3
# INFO  @ Mon, 17 Feb 2025 16:05:30: #1  total fragments in treatment: 60000000
# INFO  @ Mon, 17 Feb 2025 16:05:30: #1 finished!
# INFO  @ Mon, 17 Feb 2025 16:05:30: #2 Build Peak Model...
# INFO  @ Mon, 17 Feb 2025 16:05:30: #2 Skipped...
# INFO  @ Mon, 17 Feb 2025 16:05:30: #3 Call peaks...
# INFO  @ Mon, 17 Feb 2025 16:05:30: # local lambda is disabled!
# INFO  @ Mon, 17 Feb 2025 16:05:30: #3 !!!! DYNAMIC LAMBDA IS DISABLED !!!!
# INFO  @ Mon, 17 Feb 2025 16:05:30: #3 Going to call summits inside each peak ...
# INFO  @ Mon, 17 Feb 2025 16:05:30: #3 Pre-compute pvalue-qvalue table...
# INFO  @ Mon, 17 Feb 2025 16:05:44: #3 In the peak calling step, the following will be performed simultaneously:
# INFO  @ Mon, 17 Feb 2025 16:05:44: #3   Write bedGraph files for treatment pileup (after scaling if necessary)... chromvar_all_treat_pileup.bdg
# INFO  @ Mon, 17 Feb 2025 16:05:44: #3   Write bedGraph files for control lambda (after scaling if necessary)... chromvar_all_control_lambda.bdg
# INFO  @ Mon, 17 Feb 2025 16:05:44: #3   --SPMR is requested, so pileup will be normalized by sequencing depth in million reads.
# INFO  @ Mon, 17 Feb 2025 16:05:44: #3 Call peaks for each chromosome...
# INFO  @ Mon, 17 Feb 2025 16:06:42: #4 Write output xls file... /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2/chromvar_all_peaks.xls
# INFO  @ Mon, 17 Feb 2025 16:06:43: #4 Write peak in narrowPeak format file... /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2/chromvar_all_peaks.narrowPeak
# INFO  @ Mon, 17 Feb 2025 16:06:43: #4 Write summits bed file... /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_scprinter_supp/macs2/chromvar_all_summits.bed
# INFO  @ Mon, 17 Feb 2025 16:06:43: Done!
# Reading in peak summit file(s):
# NOTE: Assuming all start coordinates are 0-based ..
#
# Padding peak summits by: 400 bp on either side for
# Removing peaks overlapping with blacklisted regions and out of bound peaks based on chromosome sizes ..
#
# Filtering overlapping peaks based on peak summit score ..
# round: 1 181882 peaks unresolved 116439 peaks selected
# round: 2 19019 peaks unresolved 8622 peaks selected
# round: 3 3979 peaks unresolved 1391 peaks selected
# round: 4 1192 peaks unresolved 348 peaks selected
# round: 5 400 peaks unresolved 101 peaks selected
# round: 6 156 peaks unresolved 36 peaks selected
# round: 7 57 peaks unresolved 15 peaks selected
# round: 8 24 peaks unresolved 5 peaks selected
# round: 9 6 peaks unresolved 1 peaks selected
# round: 10 1 peaks unresolved 1 peaks selected
# finish clearing
# finish sorting
# finished summary

# %%
# we can compare two sets of peaks with different preset
print (pd.DataFrame(printer.uns["peak_calling"]['all_cleaned'][:]))
# Out:
#            0          1          2                3        4        5    6  \
# 0       chr1     816850     817850      all_peak_54  149.012  149.012  all
# 1       chr1     826420     827420     all_peak_55a  21.4443  21.4443  all
# 2       chr1     827037     828037     all_peak_55b  919.864  919.864  all
# 3       chr1     828500     829500      all_peak_56  6.72844  6.72844  all
# 4       chr1     843661     844661     all_peak_57a  6.03617  6.03617  all
# ...      ...        ...        ...              ...      ...      ...  ...
# 296064  chrX  155768168  155769168  all_peak_207726  6.72844  6.72844  all
# 296065  chrX  155819803  155820803  all_peak_207727   27.628   27.628  all
# 296066  chrX  155841026  155842026  all_peak_207728  35.3259  35.3259  all
# 296067  chrX  155880773  155881773  all_peak_207729   652.67   652.67  all
# 296068  chrX  155972177  155973177  all_peak_207730  2.47909  2.47909  all
#
#              7
# 0        31133
# 1        93384
# 2         7993
# 3       168939
# 4       169413
# ...        ...
# 296064  166311
# 296065   82302
# 296066   73089
# 296067   10829
# 296068  264718
#
# [296069 rows x 8 columns]

# %%
print (pd.DataFrame(printer.uns["peak_calling"]['chromvar_all_cleaned'][:]))
# Out:
#            0          1          2                          3        4  \
# 0       chr1     817200     817500       chromvar_all_peak_34  146.574
# 1       chr1     827387     827687      chromvar_all_peak_35b  916.665
# 2       chr1     844607     844907      chromvar_all_peak_36c  12.9478
# 3       chr1     858011     858311       chromvar_all_peak_37  13.8403
# 4       chr1     865660     865960       chromvar_all_peak_38  104.183
# ...      ...        ...        ...                        ...      ...
# 126954  chrX  155632509  155632809   chromvar_all_peak_117522  48.6245
# 126955  chrX  155767443  155767743  chromvar_all_peak_117523a  21.4989
# 126956  chrX  155820153  155820453   chromvar_all_peak_117524  25.6312
# 126957  chrX  155841376  155841676   chromvar_all_peak_117525  33.2717
# 126958  chrX  155881123  155881423   chromvar_all_peak_117526  649.668
#
#               5             6      7
# 0       146.574  chromvar_all  25138
# 1       916.665  chromvar_all   7304
# 2       12.9478  chromvar_all  77437
# 3       13.8403  chromvar_all  74619
# 4       104.183  chromvar_all  30857
# ...         ...           ...    ...
# 126954  48.6245  chromvar_all  46051
# 126955  21.4989  chromvar_all  65084
# 126956  25.6312  chromvar_all  60121
# 126957  33.2717  chromvar_all  54528
# 126958  649.668  chromvar_all   9604
#
# [126959 rows x 8 columns]

# %% [markdown]
# seq2PRINT preset usually leads to more peaks that are overlapping with each other, while chromvar prest results in fewer peaks that are non-overlapping.

# %% [markdown]
# ## Training separate seq2PRINT models for each sample

# %%
import json
model_configs = []
if not os.path.exists(os.path.join(work_dir, 'configs')):
    os.makedirs(os.path.join(work_dir, 'configs'))
for sample in samples:
    # For exploratory analyses we run only one fold. For publication results you can run all 5 fold for slight improvement in accuracy.
    # If you want to run all five folds, add a for-loop layer "for fold in range(5)". This way each sample will have 5 models trained.
    fold=0 
    model_config= scp.tl.seq_model_config(printer,
                                     region_path=f'{work_dir}/seq2print_cleaned_narrowPeak.bed',
                                     cell_grouping=[sample],
                                     group_names=sample,
                                     genome=printer.genome,
                                     fold=fold, 
                                     overwrite_bigwig=False,
                                     model_name='PBMC_bulkATAC_' + sample,
                                     additional_config={
                                        "notes": "v3",
                                        "tags": ["PBMC_bulkATAC", sample, 
                                            f"fold{fold}"]},
                                     path_swap=(work_dir, ''),
                                     config_save_path=f'{work_dir}/configs/PBMC_bulkATAC_{sample}_fold{fold}.JSON')
    model_configs.append(model_config)
# Out:
# Loading insertion profiles
# Creating bigwig for Bcell_0
#   0%|          | 0/24 [00:00<?, ?it/s]
# Creating bigwig for Bcell_1
#   0%|          | 0/24 [00:00<?, ?it/s]
# Creating bigwig for Monocyte_0
#   0%|          | 0/24 [00:00<?, ?it/s]
# Creating bigwig for Monocyte_1
#   0%|          | 0/24 [00:00<?, ?it/s]
# Creating bigwig for Tcell_0
#   0%|          | 0/24 [00:00<?, ?it/s]
# Creating bigwig for Tcell_1
#   0%|          | 0/24 [00:00<?, ?it/s]

# %% [markdown]
# Below we generate the commands to run in the terminal to launch our training process (copy the generated command into a terminal and run). Before launching the training process, it is recommended to install wandb and use it to track the training process. You can first register an account on https://wandb.ai/, then you can activate your mamba/conda environment such as mamba activate scprinter, and install wandb using mamba install wandb. Then you can login via wandb login. This will connect your mamba/conda env with your wandb account. More information on wandb can be found in their quick start guide at https://docs.wandb.ai/quickstart/

# %% [markdown]
# Before running the generated commands, you can run nvtop first to check which GPUs are available. This is especially important when you share the same server with other users. The training job is rather computational intensive and usually one job could take a whole GPU. Therefore, we recommend you manually set the CUDA_VISIBLE_DEVICES in the commands to the fully free GPUs.

# %% [markdown]
# When you run the command in the terminal, make sure you are in the scprinter mamba environment. To run multiple training jobs in parallel you can add & to the end of each command, such as ```CUDA_VISIBLE_DEVICES=0 seq2print_train --config /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Bcell_0_fold0.JSON --temp_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /data/mhorlbec/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb &```

# %%
for path in ['temp','model']:
    if not os.path.exists(os.path.join(work_dir, path)):
        os.makedirs(os.path.join(work_dir, path))

for sample in samples:
    scp.tl.launch_seq2print(model_config_path=f'{work_dir}/configs/PBMC_bulkATAC_{sample}_fold{fold}.JSON',
                            temp_dir=f'{work_dir}/temp',
                            model_dir=f'{work_dir}/model',
                            data_dir=work_dir,
                            gpus=samples.index(sample),
                            wandb_project='scPrinter_seq_PBMC_bulkATAC', # wandb helps you manage loggins
                            verbose=False,
                            launch=False # launch=True, this command would launch the scripts directly,
                            # otherwise, it will just display the commands, you should copy them and run them.
                           )
# Out:
# CUDA_VISIBLE_DEVICES=0 seq2print_train --config /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Bcell_0_fold0.JSON --temp_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb
# CUDA_VISIBLE_DEVICES=1 seq2print_train --config /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Bcell_1_fold0.JSON --temp_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb
# CUDA_VISIBLE_DEVICES=2 seq2print_train --config /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Monocyte_0_fold0.JSON --temp_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb
# CUDA_VISIBLE_DEVICES=3 seq2print_train --config /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Monocyte_1_fold0.JSON --temp_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb
# CUDA_VISIBLE_DEVICES=4 seq2print_train --config /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Tcell_0_fold0.JSON --temp_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb
# CUDA_VISIBLE_DEVICES=5 seq2print_train --config /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/configs/PBMC_bulkATAC_Tcell_1_fold0.JSON --temp_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/temp --model_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model --data_dir /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print --project scPrinter_seq_PBMC_bulkATAC --enable_wandb

# %% [markdown]
# ## Generate TF binding scores for each sample

# %%
# Now fetch models:
import wandb

# Login to your W&B account
wandb.login()

# Set your entity and project
entity = 'ruochiz'  # Replace with your W&B entity (username or team name)
project = 'scPrinter_seq_PBMC_bulkATAC'  # Replace with your W&B project name

# Initialize the API
api = wandb.Api()

# Get the project
runs = api.runs(f"{entity}/{project}")

pretrain_models = []
model_path_dict = {}
for run in runs:
    if run.state != 'finished':
        continue
    if 'PBMC_bulkATAC' in run.tags:
        sample = [i for i in run.tags if i in samples][0]
        model_name = run.config['savename'] + '-' + run.name + '.pt'
        model_path = os.path.join(work_dir, "model", model_name)
        model_path_dict[sample] = model_path

# %%
regions_dict = {
    'chr11:47378230-47379030': 'SPI1', # Highly expressed in monocytes and B cells
    'chr5:140633035-140633835': 'CD14', # Monocyte marker
    'chr19:41876833-41877633': 'CD79a', # B cell marker
    'chr11:118342294-118343094': 'CD3D', # T cell marker
    'chr17:58281312-58282112': 'MPO', # Monocyte marker
    'chr16:31259594-31260394': 'ITGAM', # Expressed in myeloid cells (including monocyte)
    'chr3:39281281-39282081': 'CX3CR1', # A pretty important gene driving disease-related monocyte cell states
}

# Save example regions to a bed file
regions_df = []
for region in regions_dict:
    regions_df.append(re.split("[:-]", region))
regions_df = pd.DataFrame(regions_df)
regions_df.to_csv(f'{work_dir}/regions_test.bed',
                  sep='\t', header=False, index=False)

# %% [markdown]
# Below we launch the compute for TF binding scores. When we are only testing on a small number of regions or samples, we can set return_adata to be True so that the results can be returned also in an anndata object. If the number of regions or samples is big please set it to False so it doesn't take up all the memory.

# %% [markdown]
# Remember to check nvtop to select available GPUs using the "gpus" argument.

# %%
import json
adata_tfbs = {}
for sample_ind, sample in enumerate(samples):
    adata_tfbs[sample] = scp.tl.seq_tfbs_seq2print(seq_attr_count=None,
                          seq_attr_footprint=None,
                          genome=printer.genome,
                          region_path=f'{work_dir}/regions_test.bed',
                          gpus=[5,6,7], # change it to the available gpus
                          model_type='seq2print',
                          model_path=model_path_dict[sample], # For now we just run on one fold but you can provide a list of paths to all 5 folds
                          lora_config=json.load(open(f'{work_dir}/configs/PBMC_bulkATAC_{sample}_fold0.JSON', 'r')),
                          group_names=[sample],
                          verbose=False,
                          launch=True,
                          return_adata=True, # turn this as True
                          overwrite_seqattr=True,
                          post_normalize=False,
                          save_key=f'PBMC_bulkATAC_{sample}', # and input a save_key
                          save_path=work_dir)
# Out:
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-serene-fire-7.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_0 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:00<00:00,  1.41it/s]
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.12s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-serene-fire-7.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_0 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.35s/it]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:00<00:00,  1.14it/s]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.31s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-serene-fire-7.pt_PBMC_bulkATAC_Bcell_0/attr.count.shap_hypo_0_.0.85.npz --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-serene-fire-7.pt_PBMC_bulkATAC_Bcell_0/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Bcell_0 --gpus 5 6 7 --write_numpy  --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Bcell_0 --read_numpy
# gpu 5
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# (1, 7, 800)
# obs=groups, var=regions
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-lucky-snowflake-10.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_1 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:00<00:00,  1.40it/s]
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.08s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-lucky-snowflake-10.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_1 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.86s/it]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.67s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-lucky-snowflake-10.pt_PBMC_bulkATAC_Bcell_1/attr.count.shap_hypo_0_.0.85.npz --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-lucky-snowflake-10.pt_PBMC_bulkATAC_Bcell_1/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Bcell_1 --gpus 5 6 7 --write_numpy  --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Bcell_1 --read_numpy
# gpu 5
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# (1, 7, 800)
# obs=groups, var=regions
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-ethereal-star-12.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_0 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:00<00:00,  1.28it/s]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-ethereal-star-12.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_0 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.66s/it]
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.49s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-ethereal-star-12.pt_PBMC_bulkATAC_Monocyte_0/attr.count.shap_hypo_0_.0.85.npz --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-ethereal-star-12.pt_PBMC_bulkATAC_Monocyte_0/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Monocyte_0 --gpus 5 6 7 --write_numpy  --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Monocyte_0 --read_numpy
# gpu 5
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# (1, 7, 800)
# obs=groups, var=regions
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-copper-firefly-11.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_1 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:00<00:00,  1.29it/s]
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.21s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-copper-firefly-11.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_1 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.40s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-copper-firefly-11.pt_PBMC_bulkATAC_Monocyte_1/attr.count.shap_hypo_0_.0.85.npz --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-copper-firefly-11.pt_PBMC_bulkATAC_Monocyte_1/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Monocyte_1 --gpus 5 6 7 --write_numpy  --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Monocyte_1 --read_numpy
# gpu 5
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# (1, 7, 800)
# obs=groups, var=regions
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-solar-salad-9.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_0 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.63s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.65s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-solar-salad-9.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_0 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  2.00s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.25s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.89s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-solar-salad-9.pt_PBMC_bulkATAC_Tcell_0/attr.count.shap_hypo_0_.0.85.npz --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-solar-salad-9.pt_PBMC_bulkATAC_Tcell_0/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Tcell_0 --gpus 5 6 7 --write_numpy  --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Tcell_0 --read_numpy
# gpu 5
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# (1, 7, 800)
# obs=groups, var=regions
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-balmy-water-8.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_1 --overwrite  --write_numpy  --model_norm count --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:00<00:00,  1.37it/s]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.6-9.
# hypo.count.shap_hypo_0_.0.85.6-9.npz
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.23s/it]
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.26s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-3.
# hypo.count.shap_hypo_0_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.3-6.
# hypo.count.shap_hypo_0_.0.85.3-6.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-balmy-water-8.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_1 --overwrite  --write_numpy  --model_norm footprint --silent
# [[None]]
# [5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on :   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.68s/it]
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.98s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.6-9.
# hypo.just_sum.shap_hypo_0-30_.0.85.6-9.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.3-6.
# hypo.just_sum.shap_hypo_0-30_.0.85.3-6.npz
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 7
# valid summits after trimming edges 7
# (7, 1)
# coverage min max 891.96387 960.1363
# valid summits after min/max count filter 7
# working on : 100%|██████████| 1/1 [00:01<00:00,  1.82s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-3.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-3.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-balmy-water-8.pt_PBMC_bulkATAC_Tcell_1/attr.count.shap_hypo_0_.0.85.npz --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-balmy-water-8.pt_PBMC_bulkATAC_Tcell_1/attr.just_sum.shap_hypo_0-30_.0.85.npz --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_test.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Tcell_1 --gpus 5 6 7 --write_numpy  --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Tcell_1 --read_numpy
# gpu 5
#   0%|          | 0/7 [00:00<?, ?it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]
# (1, 7, 800)
# obs=groups, var=regions

# %% [markdown]
# Below you can see that seq2PRINT can predict cell-type-specific TF binding consistent with known biology

# %%
if not os.path.exists(f'{work_dir}/plots'):
    os.system(f'mkdir {work_dir}/plots')
for region in regions_dict.keys():
    print(region, regions_dict[region])
    tfbs = pd.DataFrame(np.array([adata_tfbs[sample].obsm[region] for sample in samples]).squeeze(), index=samples)
    sns.heatmap(tfbs, cmap='RdBu_r')
    plt.savefig(f'{work_dir}/plots/TFBS_{region}.png')
    plt.show()
# Out:
# chr11:47378230-47379030 SPI1
# chr5:140633035-140633835 CD14
# chr19:41876833-41877633 CD79a
# chr11:118342294-118343094 CD3D
# chr17:58281312-58282112 MPO
# chr16:31259594-31260394 ITGAM
# chr3:39281281-39282081 CX3CR1

# %% [markdown]
# ### Compute TF binding scores on a larger number of peaks

# %% [markdown]
# When we run TF binding score calculation on a large number of peaks, we set return_adata=False and instead save the results only to bigwig files.

# %% [markdown]
# We first filter peaks by depth so we remove low coverage peaks and also reduce the computational load

# %%
# First construct a peak-by-cell matrix of ATAC counts
peak_path = f'{work_dir}/regions.bed'
adata = scp.pp.make_peak_matrix(printer,
                       regions=peak_path,
                       region_width=300,
                       cell_grouping=None,
                       group_names=None,
                       sparse=True)
adata.write(f'{work_dir}/cell_peak.h5ad')
# Out:
# Making peak matrix:   0%|          | 0/126959 [00:00<?, ?it/s]

# %%
# Remove regions with low coverage (helps to reduce total peak number and save time. The full list of 300k peaks contains many very weak peaks)
regions = pd.read_csv(f'{work_dir}/regions.bed', sep='\t', header=None)
adata = anndata.read_h5ad(f'{work_dir}/cell_peak.h5ad')
peak_depth = np.array(np.sum(adata.X, axis=0)).squeeze()
regions_filt = regions.iloc[np.where(peak_depth > 200)[0], :]
regions_filt.to_csv(f'{work_dir}/regions_filt.bed', 
                     sep='\t', header=False, index=False)

# %% [markdown]
# Now compute TF binding scores on the filtered list of peaks, remember to change the ```gpus``` parameter to use the GPUs available to you.

# %%
import json
for sample_ind, sample in enumerate(samples):
    scp.tl.seq_tfbs_seq2print(seq_attr_count=None,
                          seq_attr_footprint=None,
                          genome=printer.genome,
                          region_path=f'{work_dir}/regions_filt.bed',
                          gpus=[0,1,2,3,4,5,6,7],
                          model_type='seq2print',
                          model_path=model_path_dict[sample], # For now we just run on one fold
                          lora_config=json.load(open(f'{work_dir}/configs/PBMC_bulkATAC_{sample}_fold{fold}.JSON', 'r')),
                          group_names=[sample],
                          verbose=False,
                          launch=True,
                          return_adata=False, 
                          overwrite_seqattr=False,
                          post_normalize=True,
                          save_key=f'PBMC_bulkATAC_{sample}', # and input a save_key
                          save_path=work_dir)
# Out:
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-serene-fire-7.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_0 --model_norm count --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:23<00:00, 1283.96s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.28390-34068.
# hypo.count.shap_hypo_0_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:28<00:00, 1288.30s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.34068-39746.
# hypo.count.shap_hypo_0_.0.85.34068-39746.npz
# working on : 100%|██████████| 1/1 [21:29<00:00, 1289.56s/it]
# working on : 100%|██████████| 1/1 [21:33<00:00, 1293.58s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.22712-28390.
# hypo.count.shap_hypo_0_.0.85.22712-28390.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-5678.
# hypo.count.shap_hypo_0_.0.85.0-5678.npz
# working on : 100%|██████████| 1/1 [21:29<00:00, 1289.86s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.11356-17034.
# hypo.count.shap_hypo_0_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:33<00:00, 1293.26s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.5678-11356.
# hypo.count.shap_hypo_0_.0.85.5678-11356.npz
# working on : 100%|██████████| 1/1 [21:29<00:00, 1289.69s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.17034-22712.
# hypo.count.shap_hypo_0_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:31<00:00, 1291.65s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.39746-45424.
# hypo.count.shap_hypo_0_.0.85.39746-45424.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-serene-fire-7.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_0 --model_norm footprint --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:39<00:00, 1299.05s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.28390-34068.
# hypo.just_sum.shap_hypo_0-30_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:39<00:00, 1299.85s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.34068-39746.
# hypo.just_sum.shap_hypo_0-30_.0.85.34068-39746.npz
# working on : 100%|██████████| 1/1 [21:43<00:00, 1303.07s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.11356-17034.
# hypo.just_sum.shap_hypo_0-30_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:42<00:00, 1302.46s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.39746-45424.
# hypo.just_sum.shap_hypo_0-30_.0.85.39746-45424.npz
# working on : 100%|██████████| 1/1 [21:45<00:00, 1305.23s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-5678.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-5678.npz
# working on : 100%|██████████| 1/1 [21:42<00:00, 1302.05s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.5678-11356.
# hypo.just_sum.shap_hypo_0-30_.0.85.5678-11356.npz
# working on : 100%|██████████| 1/1 [21:44<00:00, 1304.08s/it]
# working on : 100%|██████████| 1/1 [21:43<00:00, 1303.10s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.17034-22712.
# hypo.just_sum.shap_hypo_0-30_.0.85.17034-22712.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.22712-28390.
# hypo.just_sum.shap_hypo_0-30_.0.85.22712-28390.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-serene-fire-7.pt_PBMC_bulkATAC_Bcell_0/attr.count.shap_hypo_0_.0.85.bigwig --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_0_fold0-serene-fire-7.pt_PBMC_bulkATAC_Bcell_0/attr.just_sum.shap_hypo_0-30_.0.85.bigwig --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Bcell_0 --gpus 0 1 2 3 4 5 6 7 --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Bcell_0 --post_normalize
# gpu 0
# 100%|██████████| 45424/45424 [00:17<00:00, 2653.07it/s]
# 100%|██████████| 45424/45424 [00:17<00:00, 2661.76it/s]
# (1, 45424, 800)
# /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Bcell_0
# 100%|██████████| 45424/45424 [00:20<00:00, 2178.89it/s]
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-lucky-snowflake-10.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_1 --model_norm count --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:25<00:00, 1285.41s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.28390-34068.
# hypo.count.shap_hypo_0_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:25<00:00, 1285.79s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.17034-22712.
# hypo.count.shap_hypo_0_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:26<00:00, 1286.83s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.22712-28390.
# hypo.count.shap_hypo_0_.0.85.22712-28390.npz
# working on : 100%|██████████| 1/1 [21:27<00:00, 1287.70s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.34068-39746.
# hypo.count.shap_hypo_0_.0.85.34068-39746.npz
# working on : 100%|██████████| 1/1 [21:28<00:00, 1288.10s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.39746-45424.
# hypo.count.shap_hypo_0_.0.85.39746-45424.npz
# working on : 100%|██████████| 1/1 [21:26<00:00, 1286.73s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.11356-17034.
# hypo.count.shap_hypo_0_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:31<00:00, 1291.21s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-5678.
# hypo.count.shap_hypo_0_.0.85.0-5678.npz
# working on : 100%|██████████| 1/1 [21:33<00:00, 1293.86s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.5678-11356.
# hypo.count.shap_hypo_0_.0.85.5678-11356.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-lucky-snowflake-10.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Bcell_1 --model_norm footprint --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:40<00:00, 1300.17s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.28390-34068.
# hypo.just_sum.shap_hypo_0-30_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:39<00:00, 1299.38s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.17034-22712.
# hypo.just_sum.shap_hypo_0-30_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:42<00:00, 1302.48s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.22712-28390.
# hypo.just_sum.shap_hypo_0-30_.0.85.22712-28390.npz
# working on : 100%|██████████| 1/1 [21:43<00:00, 1303.87s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.34068-39746.
# hypo.just_sum.shap_hypo_0-30_.0.85.34068-39746.npz
# working on : 100%|██████████| 1/1 [21:44<00:00, 1304.74s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-5678.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-5678.npz
# working on : 100%|██████████| 1/1 [21:45<00:00, 1305.73s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.39746-45424.
# hypo.just_sum.shap_hypo_0-30_.0.85.39746-45424.npz
# working on : 100%|██████████| 1/1 [21:42<00:00, 1302.86s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.11356-17034.
# hypo.just_sum.shap_hypo_0-30_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:44<00:00, 1304.81s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.5678-11356.
# hypo.just_sum.shap_hypo_0-30_.0.85.5678-11356.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-lucky-snowflake-10.pt_PBMC_bulkATAC_Bcell_1/attr.count.shap_hypo_0_.0.85.bigwig --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Bcell_1_fold0-lucky-snowflake-10.pt_PBMC_bulkATAC_Bcell_1/attr.just_sum.shap_hypo_0-30_.0.85.bigwig --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Bcell_1 --gpus 0 1 2 3 4 5 6 7 --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Bcell_1 --post_normalize
# gpu 0
# 100%|██████████| 45424/45424 [00:16<00:00, 2689.93it/s]
# 100%|██████████| 45424/45424 [00:16<00:00, 2700.97it/s]
#   0%|          | 0/45424 [00:00<?, ?it/s]
# (1, 45424, 800)
# /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Bcell_1
# 100%|██████████| 45424/45424 [00:20<00:00, 2216.70it/s]
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-ethereal-star-12.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_0 --model_norm count --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:23<00:00, 1283.83s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.22712-28390.
# hypo.count.shap_hypo_0_.0.85.22712-28390.npz
# working on : 100%|██████████| 1/1 [21:25<00:00, 1285.04s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.17034-22712.
# hypo.count.shap_hypo_0_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:27<00:00, 1287.41s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.39746-45424.
# hypo.count.shap_hypo_0_.0.85.39746-45424.npz
# working on : 100%|██████████| 1/1 [21:26<00:00, 1286.51s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.34068-39746.
# hypo.count.shap_hypo_0_.0.85.34068-39746.npz
# working on : 100%|██████████| 1/1 [21:25<00:00, 1285.01s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.28390-34068.
# hypo.count.shap_hypo_0_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:27<00:00, 1287.73s/it]
# working on : 100%|██████████| 1/1 [21:30<00:00, 1290.00s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.5678-11356.
# hypo.count.shap_hypo_0_.0.85.5678-11356.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.11356-17034.
# hypo.count.shap_hypo_0_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:31<00:00, 1291.51s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-5678.
# hypo.count.shap_hypo_0_.0.85.0-5678.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-ethereal-star-12.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_0 --model_norm footprint --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:37<00:00, 1297.54s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.28390-34068.
# hypo.just_sum.shap_hypo_0-30_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:41<00:00, 1301.71s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.39746-45424.
# hypo.just_sum.shap_hypo_0-30_.0.85.39746-45424.npz
# working on : 100%|██████████| 1/1 [21:39<00:00, 1299.94s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.22712-28390.
# hypo.just_sum.shap_hypo_0-30_.0.85.22712-28390.npz
# working on : 100%|██████████| 1/1 [21:46<00:00, 1306.37s/it]
# working on : 100%|██████████| 1/1 [21:44<00:00, 1304.58s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-5678.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-5678.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.11356-17034.
# hypo.just_sum.shap_hypo_0-30_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:44<00:00, 1304.22s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.5678-11356.
# hypo.just_sum.shap_hypo_0-30_.0.85.5678-11356.npz
# working on : 100%|██████████| 1/1 [21:43<00:00, 1303.61s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.17034-22712.
# hypo.just_sum.shap_hypo_0-30_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:44<00:00, 1304.84s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.34068-39746.
# hypo.just_sum.shap_hypo_0-30_.0.85.34068-39746.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-ethereal-star-12.pt_PBMC_bulkATAC_Monocyte_0/attr.count.shap_hypo_0_.0.85.bigwig --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_0_fold0-ethereal-star-12.pt_PBMC_bulkATAC_Monocyte_0/attr.just_sum.shap_hypo_0-30_.0.85.bigwig --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Monocyte_0 --gpus 0 1 2 3 4 5 6 7 --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Monocyte_0 --post_normalize
# gpu 0
# 100%|██████████| 45424/45424 [00:16<00:00, 2690.27it/s]
# 100%|██████████| 45424/45424 [00:16<00:00, 2750.85it/s]
#   0%|          | 0/45424 [00:00<?, ?it/s]
# (1, 45424, 800)
# /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Monocyte_0
# 100%|██████████| 45424/45424 [00:20<00:00, 2244.17it/s]
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-copper-firefly-11.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_1 --model_norm count --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:24<00:00, 1284.88s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.22712-28390.
# hypo.count.shap_hypo_0_.0.85.22712-28390.npz
# working on : 100%|██████████| 1/1 [21:27<00:00, 1287.05s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.11356-17034.
# hypo.count.shap_hypo_0_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:26<00:00, 1286.96s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.17034-22712.
# hypo.count.shap_hypo_0_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:26<00:00, 1286.33s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.28390-34068.
# hypo.count.shap_hypo_0_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:26<00:00, 1286.97s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.34068-39746.
# hypo.count.shap_hypo_0_.0.85.34068-39746.npz
# working on : 100%|██████████| 1/1 [21:27<00:00, 1287.91s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.39746-45424.
# hypo.count.shap_hypo_0_.0.85.39746-45424.npz
# working on : 100%|██████████| 1/1 [21:30<00:00, 1290.69s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-5678.
# hypo.count.shap_hypo_0_.0.85.0-5678.npz
# working on : 100%|██████████| 1/1 [21:28<00:00, 1288.30s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.5678-11356.
# hypo.count.shap_hypo_0_.0.85.5678-11356.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-copper-firefly-11.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Monocyte_1 --model_norm footprint --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:39<00:00, 1299.38s/it]
# working on : 100%|██████████| 1/1 [21:40<00:00, 1300.58s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.39746-45424.
# hypo.just_sum.shap_hypo_0-30_.0.85.39746-45424.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.28390-34068.
# hypo.just_sum.shap_hypo_0-30_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:44<00:00, 1304.35s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.11356-17034.
# hypo.just_sum.shap_hypo_0-30_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:41<00:00, 1301.12s/it]
# working on : 100%|██████████| 1/1 [21:41<00:00, 1301.31s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.22712-28390.
# hypo.just_sum.shap_hypo_0-30_.0.85.22712-28390.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.34068-39746.
# hypo.just_sum.shap_hypo_0-30_.0.85.34068-39746.npz
# working on : 100%|██████████| 1/1 [21:45<00:00, 1305.38s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.5678-11356.
# hypo.just_sum.shap_hypo_0-30_.0.85.5678-11356.npz
# working on : 100%|██████████| 1/1 [21:43<00:00, 1303.87s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.17034-22712.
# hypo.just_sum.shap_hypo_0-30_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:48<00:00, 1308.21s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-5678.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-5678.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-copper-firefly-11.pt_PBMC_bulkATAC_Monocyte_1/attr.count.shap_hypo_0_.0.85.bigwig --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Monocyte_1_fold0-copper-firefly-11.pt_PBMC_bulkATAC_Monocyte_1/attr.just_sum.shap_hypo_0-30_.0.85.bigwig --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Monocyte_1 --gpus 0 1 2 3 4 5 6 7 --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Monocyte_1 --post_normalize
# gpu 0
# 100%|██████████| 45424/45424 [00:17<00:00, 2648.43it/s]
# 100%|██████████| 45424/45424 [00:16<00:00, 2679.64it/s]
#   0%|          | 0/45424 [00:00<?, ?it/s]
# (1, 45424, 800)
# /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Monocyte_1
# 100%|██████████| 45424/45424 [00:20<00:00, 2189.80it/s]
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-solar-salad-9.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_0 --model_norm count --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:25<00:00, 1285.33s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.28390-34068.
# hypo.count.shap_hypo_0_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:28<00:00, 1288.39s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.39746-45424.
# hypo.count.shap_hypo_0_.0.85.39746-45424.npz
# working on : 100%|██████████| 1/1 [21:30<00:00, 1290.18s/it]
# working on : 100%|██████████| 1/1 [21:27<00:00, 1287.42s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.34068-39746.
# hypo.count.shap_hypo_0_.0.85.34068-39746.npz
# working on : 100%|██████████| 1/1 [21:27<00:00, 1287.77s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.22712-28390.
# hypo.count.shap_hypo_0_.0.85.22712-28390.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.17034-22712.
# hypo.count.shap_hypo_0_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:30<00:00, 1290.26s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.11356-17034.
# hypo.count.shap_hypo_0_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:29<00:00, 1289.63s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.5678-11356.
# hypo.count.shap_hypo_0_.0.85.5678-11356.npz
# working on : 100%|██████████| 1/1 [21:30<00:00, 1290.69s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-5678.
# hypo.count.shap_hypo_0_.0.85.0-5678.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-solar-salad-9.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_0 --model_norm footprint --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:39<00:00, 1299.08s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.17034-22712.
# hypo.just_sum.shap_hypo_0-30_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:39<00:00, 1299.87s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.22712-28390.
# hypo.just_sum.shap_hypo_0-30_.0.85.22712-28390.npz
# working on : 100%|██████████| 1/1 [21:42<00:00, 1302.06s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.39746-45424.
# hypo.just_sum.shap_hypo_0-30_.0.85.39746-45424.npz
# working on : 100%|██████████| 1/1 [21:43<00:00, 1303.53s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.34068-39746.
# hypo.just_sum.shap_hypo_0-30_.0.85.34068-39746.npz
# working on : 100%|██████████| 1/1 [21:40<00:00, 1300.65s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.28390-34068.
# hypo.just_sum.shap_hypo_0-30_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:41<00:00, 1301.90s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.5678-11356.
# hypo.just_sum.shap_hypo_0-30_.0.85.5678-11356.npz
# working on : 100%|██████████| 1/1 [21:48<00:00, 1308.49s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-5678.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-5678.npz
# working on : 100%|██████████| 1/1 [21:43<00:00, 1303.23s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.11356-17034.
# hypo.just_sum.shap_hypo_0-30_.0.85.11356-17034.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-solar-salad-9.pt_PBMC_bulkATAC_Tcell_0/attr.count.shap_hypo_0_.0.85.bigwig --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_0_fold0-solar-salad-9.pt_PBMC_bulkATAC_Tcell_0/attr.just_sum.shap_hypo_0-30_.0.85.bigwig --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Tcell_0 --gpus 0 1 2 3 4 5 6 7 --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Tcell_0 --post_normalize
# gpu 0
# 100%|██████████| 45424/45424 [00:17<00:00, 2647.61it/s]
# 100%|██████████| 45424/45424 [00:16<00:00, 2701.75it/s]
#   0%|          | 0/45424 [00:00<?, ?it/s]
# (1, 45424, 800)
# /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Tcell_0
# 100%|██████████| 45424/45424 [00:20<00:00, 2209.36it/s]
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-balmy-water-8.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper count --nth_output 0 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_1 --model_norm count --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:22<00:00, 1282.95s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.17034-22712.
# hypo.count.shap_hypo_0_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:25<00:00, 1285.28s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.22712-28390.
# hypo.count.shap_hypo_0_.0.85.22712-28390.npz
# working on : 100%|██████████| 1/1 [21:25<00:00, 1285.25s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.11356-17034.
# hypo.count.shap_hypo_0_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:22<00:00, 1282.59s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.28390-34068.
# hypo.count.shap_hypo_0_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:28<00:00, 1288.18s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.5678-11356.
# hypo.count.shap_hypo_0_.0.85.5678-11356.npz
# working on : 100%|██████████| 1/1 [21:30<00:00, 1290.19s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.0-5678.
# hypo.count.shap_hypo_0_.0.85.0-5678.npz
# working on : 100%|██████████| 1/1 [21:26<00:00, 1286.62s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.39746-45424.
# hypo.count.shap_hypo_0_.0.85.39746-45424.npz
# working on : 100%|██████████| 1/1 [21:27<00:00, 1287.50s/it]
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.34068-39746.
# hypo.count.shap_hypo_0_.0.85.34068-39746.npz
# saving attrs
# using pre-calculated norm key count
# filename_template {type}.count.shap_hypo_0_.0.85.
# hypo.count.shap_hypo_0_.0.85.npz
# seq2print_attr --pt /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-balmy-water-8.pt --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --method shap_hypo --wrapper just_sum --nth_output 0-30 --gpus 0 1 2 3 4 5 6 7 --genome hg38 --decay 0.85 --save_key PBMC_bulkATAC_Tcell_1 --model_norm footprint --silent
# [[None]]
# [0, 1, 2, 3, 4, 5, 6, 7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [0]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [3]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [5]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [2]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# [[None]]
# [1]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [7]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [6]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
#   0%|          | 0/1 [00:00<?, ?it/s]
# [[None]]
# [4]
# signal_window 1000 dna_len 1840
# input summits 45424
# valid summits after trimming edges 45424
# (45424, 1)
# coverage min max 706.8145 1302.4551
# valid summits after min/max count filter 45424
# working on : 100%|██████████| 1/1 [21:39<00:00, 1299.53s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.28390-34068.
# hypo.just_sum.shap_hypo_0-30_.0.85.28390-34068.npz
# working on : 100%|██████████| 1/1 [21:40<00:00, 1300.18s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.11356-17034.
# hypo.just_sum.shap_hypo_0-30_.0.85.11356-17034.npz
# working on : 100%|██████████| 1/1 [21:41<00:00, 1301.80s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.17034-22712.
# hypo.just_sum.shap_hypo_0-30_.0.85.17034-22712.npz
# working on : 100%|██████████| 1/1 [21:43<00:00, 1303.38s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.5678-11356.
# hypo.just_sum.shap_hypo_0-30_.0.85.5678-11356.npz
# working on : 100%|██████████| 1/1 [21:43<00:00, 1303.98s/it]
# working on : 100%|██████████| 1/1 [21:46<00:00, 1306.34s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.39746-45424.
# hypo.just_sum.shap_hypo_0-30_.0.85.39746-45424.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.0-5678.
# hypo.just_sum.shap_hypo_0-30_.0.85.0-5678.npz
# working on : 100%|██████████| 1/1 [21:42<00:00, 1302.45s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.22712-28390.
# hypo.just_sum.shap_hypo_0-30_.0.85.22712-28390.npz
# working on : 100%|██████████| 1/1 [21:43<00:00, 1303.42s/it]
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.34068-39746.
# hypo.just_sum.shap_hypo_0-30_.0.85.34068-39746.npz
# saving attrs
# using pre-calculated norm key footprint
# filename_template {type}.just_sum.shap_hypo_0-30_.0.85.
# hypo.just_sum.shap_hypo_0-30_.0.85.npz
# seq2print_tfbs --count_pt /home/rzhang/.cache/scprinter/TFBS_0_conv_v2.pt --foot_pt /home/rzhang/.cache/scprinter/TFBS_1_conv_v2.pt --seq_count /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-balmy-water-8.pt_PBMC_bulkATAC_Tcell_1/attr.count.shap_hypo_0_.0.85.bigwig --seq_foot /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/model/PBMC_bulkATAC_Tcell_1_fold0-balmy-water-8.pt_PBMC_bulkATAC_Tcell_1/attr.just_sum.shap_hypo_0-30_.0.85.bigwig --genome hg38 --peaks /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/regions_filt.bed --save_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Tcell_1 --gpus 0 1 2 3 4 5 6 7 --collection_name /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/PBMC_bulkATAC_Tcell_1 --post_normalize
# gpu 0
# 100%|██████████| 45424/45424 [00:19<00:00, 2382.71it/s]
# 100%|██████████| 45424/45424 [00:19<00:00, 2384.73it/s]
# (1, 45424, 800)
# /ewsc/rzhang/250204_scPrinter_tutorial/PBMC_bulkATAC_tutorial//seq2print/Tcell_1
# 100%|██████████| 45424/45424 [00:23<00:00, 1948.06it/s]

# %%
# We first scan TF motifs across all regions to find motif matched sites

# Initialize motif set object
motifs = scp.motifs.FigR_Human_Motifs(genome=printer.genome, bg=[0.25] * 4)

# Prepare motif scanner. Here you can specify which TF motifs you want to scan using tf_genes. If tf_genes=None then use all motifs
motifs.prep_scanner()

# Scan motif sites. This will return the exact genomic coordinates of motif matches
motif_sites = motifs.scan_motif(regions_filt, verbose=True, clean=True)

# Reformat motif matches to a pandas DataFrame
motif_sites = pd.DataFrame(motif_sites)
motif_sites.iloc[:, 2] = motif_sites.iloc[:, 1] + motif_sites.iloc[:, 8]
motif_sites.iloc[:, 1] = motif_sites.iloc[:, 1] + motif_sites.iloc[:, 7]
motif_sites = motif_sites.iloc[:, [0,1,2,4]]
motif_sites.columns=["chrom", "start", "end", "TF"]
# Out:
#   0%|          | 0/90848 [00:00<?, ?it/s]

# %%
# We then extract the TF binding scores at those motif sites
def fetch_bw(args):
    import pyBigWig as pw
    
    TFBS, bw, genome = args
    chroms, starts, ends = np.array(TFBS['chrom']),np.array(TFBS['start']),np.array(TFBS['end'])
    res_all = {}
    with pw.open(bw, 'r') as f:
        for chrom in tqdm(genome.chrom_sizes):
            if chrom == 'chrY':
                continue
            res_all[chrom] = f.values(chrom, 0, genome.chrom_sizes[chrom], numpy=True)
        
    vs = []
    for chr, left, right in zip(tqdm(chroms, mininterval=1), starts, ends):
        vs.append(np.nanmean(res_all[chr][left:right]))
    return vs

# Multi-process loading of TF binding scores 
bigwig_dict = {sample:f"{work_dir}/{sample}_TFBS.bigwig" for sample in samples}
args = [[motif_sites, bigwig_dict[sample], printer.genome] for sample in samples]
n_jobs = 4
import multiprocessing as mp
with mp.Pool(n_jobs) as pool:
    TFBS_scores = list(pool.imap(fetch_bw, args))
TFBS_scores = np.array(TFBS_scores).T
TFBS_scores = pd.DataFrame(TFBS_scores, columns=[f"TFBS_{sample}" for sample in samples])
TFBS_scores = pd.concat([motif_sites, TFBS_scores], axis=1)

# %%
TFBS_scores.head()
# Out:
#   chrom   start     end     TF  TFBS_Bcell_0  TFBS_Bcell_1  TFBS_Monocyte_0  \
# 0  chr1  817402  817410   GFI1      0.057961      0.049834         0.111100
# 1  chr1  817211  817218   HBP1      0.039174      0.032866         0.031825
# 2  chr1  817326  817346   IRF1      0.100936      0.081488         0.162958
# 3  chr1  817323  817348   IRF3      0.099807      0.081332         0.155246
# 4  chr1  817352  817360  NR2E1      0.082241      0.072450         0.146264
#
#    TFBS_Monocyte_1  TFBS_Tcell_0  TFBS_Tcell_1
# 0         0.105341      0.052458      0.051745
# 1         0.035802      0.014630      0.015590
# 2         0.155032      0.035244      0.040355
# 3         0.147663      0.037275      0.041037
# 4         0.144592      0.040891      0.044375

# %%
fig, ax = plt.subplots(2,2, figsize=(7,6))

scores = TFBS_scores.loc[TFBS_scores.TF.values == "CEBPA", :]
ax[0][0].scatter(
    np.mean(scores.loc[:, [f"TFBS_Monocyte_{i}" for i in range(2)]], axis=1), 
    np.mean(scores.loc[:, [f"TFBS_Tcell_{i}" for i in range(2)]], axis=1), s=0.01)
ax[0][0].set_xlabel("Monocyte TFBS")
ax[0][0].set_ylabel("T cell TFBS")
ax[0][0].set_title("CEBPA")
plt.tight_layout()

scores = TFBS_scores.loc[TFBS_scores.TF.values == "SPI1", :]
ax[0][1].scatter(
    np.mean(scores.loc[:, [f"TFBS_Tcell_{i}" for i in range(2)]], axis=1), 
    np.mean(scores.loc[:, [f"TFBS_Bcell_{i}" for i in range(2)]], axis=1), s=0.01)
ax[0][1].set_xlabel("T cell TFBS")
ax[0][1].set_ylabel("B cell TFBS")
ax[0][1].set_title("SPI1")
plt.tight_layout()

scores = TFBS_scores.loc[TFBS_scores.TF.values == "PAX5", :]
ax[1][0].scatter(
    np.mean(scores.loc[:, [f"TFBS_Tcell_{i}" for i in range(2)]], axis=1), 
    np.mean(scores.loc[:, [f"TFBS_Bcell_{i}" for i in range(2)]], axis=1), s=0.01)
ax[1][0].set_xlabel("T cell TFBS")
ax[1][0].set_ylabel("B cell TFBS")
ax[1][0].set_title("PAX5")
plt.tight_layout()

scores = TFBS_scores.loc[TFBS_scores.TF.values == "RUNX3", :]
ax[1][1].scatter(
    np.mean(scores.loc[:, [f"TFBS_Tcell_{i}" for i in range(2)]], axis=1), 
    np.mean(scores.loc[:, [f"TFBS_Bcell_{i}" for i in range(2)]], axis=1), s=0.01)
ax[1][1].set_xlabel("T cell TFBS")
ax[1][1].set_ylabel("B cell TFBS")
ax[1][1].set_title("RUNX3")

plt.show()

# %% [markdown]
# From the above results we clearly see that the model predicts elevated binding of CEBPA in monocytes compared to T cells, as well as higher binding of SPI1 in B cells compared to T cells, higher binding of PAX5 in B cells compared to T cells, and higher binding of RUNX in T cells compared to B cells. From the scatter plot, it was a bit hard to see whether RUNX overall gained binding or lost binding in T cells compared to B cells, so now we calculate the difference of binding at each site, and compare all sites where the absolute value of change is above a certain threhsold (let's do 0.05 for now), and then it becomes clear that RUNX binding is higher in T cells.

# %%
scores = TFBS_scores.loc[TFBS_scores.TF.values == "RUNX3", :]
Tcell_scores = np.mean(scores.loc[:, [f"TFBS_Tcell_{i}" for i in range(2)]], axis=1)
Bcell_scores = np.mean(scores.loc[:, [f"TFBS_Bcell_{i}" for i in range(2)]], axis=1)
diff = Tcell_scores - Bcell_scores
diff = diff[np.abs(diff) > 0.05]
plt.hist(diff, bins=100)
plt.show()

# %% [markdown]
# **Always, always remember to close the object!**

# %%
printer.close()

# %% [markdown]
# We hope this tutorial is helpful for you and if you run into any issues please feel free to open a GitHub issue at https://github.com/buenrostrolab/scPrinter!
